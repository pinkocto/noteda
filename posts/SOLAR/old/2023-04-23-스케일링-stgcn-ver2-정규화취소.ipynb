# %% [raw]
# ---
# title: " **[SOLAR]** STGCN Ver2 (data2, -N +S) 30회"
# author: "JiyunLim"
# date: "04/23/2023"
# categories:
#   - Research
#   - STGCN
#   - SOLAR
# ---

# %% [markdown]
# # STGCN Ver2

# %% [markdown]
# ## ref
# - <https://github.com/miruetoto/yechan3/tree/main/posts/3_Researches/ITSTGCN/itstgcn>
# - <https://miruetoto.github.io/yechan3/posts/3_Researches/ITSTGCN/2023-03-18-SimulationPlanner-Tutorial.html#plnr_gnar_block>

# %% [markdown]
# ## 2022/06/01 ~ 2022/09/15
#
# - train 2022-06-01 00:00:00 ~ 2022-08-14 17:00:00
# - test 2022-08-14 18:00:00 ~ 2022-09-15 23:00:00

# %% [markdown]
# ## Import

# %%
import eptstgcn
import torch
import eptstgcn.planner

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
url = "https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data2/stgcn_data2.json"
loader = eptstgcn.DatasetLoader(url)
dataset = loader.get_dataset(lags=4)

# %%
train_dataset, test_dataset = eptstgcn.utils.temporal_signal_split(dataset, train_ratio = 0.7)

# %% [markdown]
# ## LRNR

# %% [markdown]
# - ref: <https://seoyeonc.github.io/blog/posts/GCN/2023-03-17-ITSTGCN-Tutorial.html>

# %%
lrnr = eptstgcn.StgcnLearner(train_dataset, dataset_name = 'data2(2022/06/01 ~ 2022/09/15)')

# %%
lrnr.learn(filters=32, epoch=50)
# Out:
# 50/50

# %%
# import pickle 
# with open('./lrnr_model/stgcn_ver2_data2_cancel_normal.pickle','wb') as fw:
#     pickle.dump(lrnr, fw)

# %%
import pickle 
with open('./lrnr_model/stgcn_ver2_data2_cancel_normal.pickle', 'rb') as f: 
    model = pickle.load(f)

# %% [markdown]
# ## Visualization

# %%
evtor = eptstgcn.Evaluator(model, train_dataset, test_dataset)

# %%
# fig = evtor.plot('--', label='observed data')
# fig.tight_layout()
# fig

# %% [markdown]
# ### train

# %%
evtor.tr_plot(t=150, label='observed data')

# %% [markdown]
# ### test

# %%
evtor.test_plot(t=150, label='observed data')

# %% [markdown]
# ## Simulation

# %%
plans_stgcn = {
    'max_iteration': 30, 
    'method': ['EPT-STGCN'], 
    'lags': [4], 
    'nof_filters': [32], 
    'epoch': [50]
}

# %%
# plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
# plnr.simulate()
# Out:
# 1/30 is done
# 2/30 is done
# 3/30 is done
# 4/30 is done
# 5/30 is done
# 6/30 is done
# 7/30 is done
# 8/30 is done
# 9/30 is done
# 10/30 is done
# 11/30 is done
# 12/30 is done
# 13/30 is done
# 14/30 is done
# 15/30 is done
# 16/30 is done
# 17/30 is done
# 18/30 is done
# 19/30 is done
# 20/30 is done
# 21/30 is done
# 22/30 is done
# 23/30 is done
# 24/30 is done
# 25/30 is done
# 26/30 is done
# 27/30 is done
# 28/30 is done
# 29/30 is done
# 30/30 is done
# All results are stored in ./simulation_results/2023-04-23_01-41-09.csv

# %%
# import pickle
# with open('./simul_model/stgcn_ver2_data2_cancel_normal.pickle', 'wb') as fw:
#     pickle.dump(plnr, fw)

# %%
with open('./simul_model/stgcn_ver2_data2_cancel_normal.pickle', 'rb') as f:
    simul_model = pickle.load(f)

# %%
df_simul_no = simul_model.simulation_results
df_simul_no
# Out:
#    dataset     method lags nof_filters epoch mse(train) mse(test)  \
# 0    data2  EPT-STGCN    4          32    50   0.207058  0.192318
# 1    data2  EPT-STGCN    4          32    50   0.183151  0.166525
# 2    data2  EPT-STGCN    4          32    50   0.187727  0.170964
# 3    data2  EPT-STGCN    4          32    50   0.183493  0.165333
# 4    data2  EPT-STGCN    4          32    50   0.183788  0.163304
# 5    data2  EPT-STGCN    4          32    50   0.184463  0.166215
# 6    data2  EPT-STGCN    4          32    50   0.184557  0.168805
# 7    data2  EPT-STGCN    4          32    50   0.182589   0.16412
# 8    data2  EPT-STGCN    4          32    50    0.18965  0.168722
# 9    data2  EPT-STGCN    4          32    50   0.181751  0.161628
# 10   data2  EPT-STGCN    4          32    50   0.193702  0.174698
# 11   data2  EPT-STGCN    4          32    50   0.186056  0.169208
# 12   data2  EPT-STGCN    4          32    50   0.183449  0.164652
# 13   data2  EPT-STGCN    4          32    50   0.181829  0.164456
# 14   data2  EPT-STGCN    4          32    50   0.181213  0.162173
# 15   data2  EPT-STGCN    4          32    50   0.185801  0.163754
# 16   data2  EPT-STGCN    4          32    50   0.180674  0.162226
# 17   data2  EPT-STGCN    4          32    50   0.183327  0.165314
# 18   data2  EPT-STGCN    4          32    50   0.188633  0.171534
# 19   data2  EPT-STGCN    4          32    50   0.183651  0.162947
# 20   data2  EPT-STGCN    4          32    50   0.181314   0.16315
# 21   data2  EPT-STGCN    4          32    50   0.189536  0.173027
# 22   data2  EPT-STGCN    4          32    50   0.194188  0.180879
# 23   data2  EPT-STGCN    4          32    50    0.19195  0.173795
# 24   data2  EPT-STGCN    4          32    50   0.201777  0.183143
# 25   data2  EPT-STGCN    4          32    50   0.188091  0.170836
# 26   data2  EPT-STGCN    4          32    50   0.184508  0.163219
# 27   data2  EPT-STGCN    4          32    50   0.187269  0.170395
# 28   data2  EPT-STGCN    4          32    50   0.184121  0.163209
# 29   data2  EPT-STGCN    4          32    50   0.195845  0.175516
#
#    calculation_time
# 0        405.406879
# 1        406.358098
# 2         405.92099
# 3        405.771331
# 4         406.80101
# 5        404.526357
# 6        404.531185
# 7        403.679201
# 8        404.699471
# 9        404.820747
# 10       404.747668
# 11       405.390504
# 12       418.454221
# 13       431.528654
# 14       407.844052
# 15       411.968251
# 16       409.180396
# 17       410.445006
# 18       410.336946
# 19       407.536792
# 20        407.53003
# 21       407.360921
# 22        407.03145
# 23       406.137764
# 24       409.344015
# 25       408.617722
# 26       407.710896
# 27       408.118827
# 28       407.103555
# 29       373.846944

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_simul_no['mse(test)'])
plt.show()
