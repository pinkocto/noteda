# %% [raw]
# ---
# title: " **[SOLAR]** STGCN Ver1 (data2, -N +S) 30회 100epoch"
# author: "JiyunLim"
# date: "04/25/2023"
# categories:
#   - Research
#   - STGCN
#   - SOLAR
# ---

# %% [markdown]
# # STGCN Ver1

# %% [markdown]
# ## ref
# - <https://github.com/miruetoto/yechan3/tree/main/posts/3_Researches/ITSTGCN/itstgcn>
# - <https://miruetoto.github.io/yechan3/posts/3_Researches/ITSTGCN/2023-03-18-SimulationPlanner-Tutorial.html#plnr_gnar_block>

# %% [markdown]
# ## 2022/06/01 ~ 2022/09/15
#
# - train 2022-06-01 00:00:00 ~ 2022-08-14 17:00:00
# - test 2022-08-14 18:00:00 ~ 2022-09-15 23:00:00

# %% [markdown]
# ## import

# %%
import eptstgcn
import torch
import eptstgcn.planner

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
url = "https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data2/stgcn_data1.json"
loader = eptstgcn.DatasetLoader(url)
dataset = loader.get_dataset(lags=4)

# %%
train_dataset, test_dataset = eptstgcn.utils.temporal_signal_split(dataset, train_ratio = 0.7)

# %% [markdown]
# ## LRNR

# %%
lrnr = eptstgcn.StgcnLearner(train_dataset, dataset_name = 'data2(2022/06/01 ~ 2022/09/15)')

# %%
lrnr.learn(filters=32, epoch=100)
# Out:
# 100/100

# %%
import pickle 
with open('./lrnr_model/stgcn_ver1_data2_cancel_normal_100epoch.pickle','wb') as fw:
    pickle.dump(lrnr, fw)

# %%
import pickle 
with open('./lrnr_model/stgcn_ver1_data2_cancel_normal_100epoch.pickle', 'rb') as f: 
    lrnr_model = pickle.load(f)

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### train

# %%
evtor = eptstgcn.Evaluator(lrnr_model, train_dataset, test_dataset)

# %%
evtor.tr_plot(t=150, label='observed data')

# %% [markdown]
# ### test

# %%
evtor.test_plot(t=150, label='observed data')

# %% [markdown]
# ## Simulation

# %%
plans_stgcn = {
    'max_iteration': 30, 
    'method': ['STGCN'], 
    'lags': [4], 
    'nof_filters': [32], 
    'epoch': [100]
}

# %%
plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
plnr.simulate()
# Out:
# 1/30 is done
# 2/30 is done
# 3/30 is done
# 4/30 is done
# 5/30 is done
# 6/30 is done
# 7/30 is done
# 8/30 is done
# 9/30 is done
# 10/30 is done
# 11/30 is done
# 12/30 is done
# 13/30 is done
# 14/30 is done
# 15/30 is done
# 16/30 is done
# 17/30 is done
# 18/30 is done
# 19/30 is done
# 20/30 is done
# 21/30 is done
# 22/30 is done
# 23/30 is done
# 24/30 is done
# 25/30 is done
# 26/30 is done
# 27/30 is done
# 28/30 is done
# 29/30 is done
# 30/30 is done
# All results are stored in ./simulation_results/2023-04-27_12-36-28.csv

# %%
import pickle
with open('./simul_model/stgcn_ver1_data2_cancel_normal_100epoch.pickle','wb') as fw:
         pickle.dump(plnr, fw)

# %%
import pickle
with open('./simul_model/stgcn_ver1_data2_cancel_normal_100epoch.pickle','rb') as f:
         simul_model = pickle.load(f)

# %%
df_simul_no = simul_model.simulation_results
df_simul_no
# Out:
#    dataset method lags nof_filters epoch mse(train) mse(test) calculation_time
# 0    data2  STGCN    4          32   100   0.189243  0.171325       772.848698
# 1    data2  STGCN    4          32   100   0.189744  0.172561       817.378381
# 2    data2  STGCN    4          32   100   0.207822  0.199035       819.180893
# 3    data2  STGCN    4          32   100   0.193168  0.179314       814.309451
# 4    data2  STGCN    4          32   100   0.188224  0.169882       815.446167
# 5    data2  STGCN    4          32   100   0.188472  0.171604       810.853826
# 6    data2  STGCN    4          32   100   0.189101  0.174505       813.963314
# 7    data2  STGCN    4          32   100   0.191105  0.178127       817.652433
# 8    data2  STGCN    4          32   100   0.189744  0.174883       864.148679
# 9    data2  STGCN    4          32   100   0.192389  0.180111       841.731307
# 10   data2  STGCN    4          32   100   0.189369  0.173519      1089.791247
# 11   data2  STGCN    4          32   100   0.194758  0.183318      1069.243364
# 12   data2  STGCN    4          32   100   0.189176  0.172478      1000.280797
# 13   data2  STGCN    4          32   100   0.190803  0.172353      2673.002033
# 14   data2  STGCN    4          32   100   0.201632  0.187346       2715.75583
# 15   data2  STGCN    4          32   100   0.192502  0.179139      2321.917715
# 16   data2  STGCN    4          32   100   0.186289  0.170343      2352.800906
# 17   data2  STGCN    4          32   100   0.184571  0.168473      2333.993101
# 18   data2  STGCN    4          32   100   0.192246  0.180119      2318.096527
# 19   data2  STGCN    4          32   100   0.202523  0.192137      2283.376323
# 20   data2  STGCN    4          32   100   0.190118  0.176027      2209.563552
# 21   data2  STGCN    4          32   100   0.192123  0.180584      2203.745355
# 22   data2  STGCN    4          32   100    0.19005  0.171991       2254.78481
# 23   data2  STGCN    4          32   100   0.189719  0.172247      2702.167613
# 24   data2  STGCN    4          32   100    0.18996   0.17706      2807.790312
# 25   data2  STGCN    4          32   100   0.186305  0.172633      2481.448381
# 26   data2  STGCN    4          32   100   0.188398  0.169128      2431.156991
# 27   data2  STGCN    4          32   100   0.189949  0.174023      2236.444541
# 28   data2  STGCN    4          32   100   0.195153  0.182603      2414.528652
# 29   data2  STGCN    4          32   100   0.192687  0.179498      1819.399718

# %%
df_simul_no['mse(test)'].mean()
# Out:
# 0.1768788566191991

# %%
print('stgcn ver1 100에폭 끝!')
# Out:
# stgcn ver1 100에폭 끝!

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_simul_no['mse(test)'])
plt.show()
