# %% [raw]
# ---
# title: " **[SOLAR]** STGCN Ver1 (data2, -N +S) 시뮬레이션(epoch, filter, lag)"
# author: "JiyunLim"
# date: "04/29/2023"
# categories:
#   - Research
#   - STGCN
#   - SOLAR
# ---

# %% [markdown]
# # STGCN Ver1

# %% [markdown]
# > 50 에폭 // 완료! (csv로 저장)
#
# > 100 에폭 // 완료!
#
# > 150 에폭 시작 (2023-05-05-오후1시54분) // 완료!
#
# ***10 iter 완료!!***

# %% [markdown]
# > 150 에폭 시작(2023-05-07 오후2시 38분 시작) // 완료! (5월 9일 오전 10시5분) -- 50epoch 해야함

# %% [markdown]
# > 100 에폭 시작(2023-05-09 오전 10시 46분 시작) // 완료 (5월 10일 정오)

# %% [markdown]
# > 50에폭 시작(2023-05-10 오후 11시 10분 시작) // 완료 (5월 11일 오후 1시 36분)

# %% [markdown]
# **20 iter 완료!!**

# %% [markdown]
# > 50 에폭 시작(2023-05-11 오후 4시 40분 시작) // 완료 (5월 12일 오전 7시)
#
# > 100 에폭 시작(2023-05-12 오전 9시 20분 시작) // 완료 (5월 13일 오후 2시 30분)
#
# > 150 에폭 시작 (2023-05-14 오전 2시 30분 시작) // 완료 (5월 15일 오후 4시 37분)

# %% [markdown]
# **30 iter 완료!!**

# %% [markdown]
# *240개 한꺼번에 저장된 파일(second/stgcn_v1_150epoch_2) -- 2iteration*

# %% [markdown]
# ## ref
# - <https://github.com/miruetoto/yechan3/tree/main/posts/3_Researches/ITSTGCN/itstgcn>
# - <https://miruetoto.github.io/yechan3/posts/3_Researches/ITSTGCN/2023-03-18-SimulationPlanner-Tutorial.html#plnr_gnar_block>

# %% [markdown]
# ## 2022/06/01 ~ 2022/09/15
#
# - train 2022-06-01 00:00:00 ~ 2022-08-14 17:00:00
# - test 2022-08-14 18:00:00 ~ 2022-09-15 23:00:00

# %% [markdown]
# # import

# %%
import eptstgcn
import torch
import eptstgcn.planner

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

# %% [markdown]
# # Read Data

# %%
url = "https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data2/stgcn_data1.json"
loader = eptstgcn.DatasetLoader(url)
# dataset = loader.get_dataset(lags=4)
# train_dataset, test_dataset = eptstgcn.utils.temporal_signal_split(dataset, train_ratio = 0.7)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## 50 epoch
# - 10iter (끝)
# - 20iter (on going)

# %%
plans_stgcn = {
    'max_iteration': 10, # 30 
    'method': ['STGCN'], 
    'lags': [4, 8, 12, 24], 
    'nof_filters': [16, 32, 64], 
    'epoch': [50] # [50, 100, 150]
}

# %%
plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
plans_stgcn
# Out:
# {'max_iteration': 10,
#  'method': ['STGCN'],
#  'lags': [4, 8, 12, 24],
#  'nof_filters': [16, 32, 64],
#  'epoch': [50]}

# %%
plnr.simulate()
eptstgcn.save_data(plnr,'./simul_model2/stgcn_v1/stgcn_v1_50epoch_3.pickle')
simul_model_50 = eptstgcn.load_data('./simul_model2/stgcn_v1/stgcn_v1_50epoch_3.pickle')
# Out:
# 1/10 is done
# 11/50

# %%
simul_model_50.simulation_results
# Out:
#     dataset method normal lags nof_filters epoch mse(train) mse(test)  \
# 0     data2  STGCN      X    4          16    50   0.183498  0.169735
# 1     data2  STGCN      X    4          32    50   0.182225  0.162033
# 2     data2  STGCN      X    4          64    50   0.183565  0.171925
# 3     data2  STGCN      X    8          16    50    0.19624  0.173633
# 4     data2  STGCN      X    8          32    50   0.197571  0.171606
# ..      ...    ...    ...  ...         ...   ...        ...       ...
# 115   data2  STGCN      X   12          32    50    0.19375  0.168965
# 116   data2  STGCN      X   12          64    50    0.19339  0.169359
# 117   data2  STGCN      X   24          16    50   0.226857  0.209055
# 118   data2  STGCN      X   24          32    50   0.257455  0.216844
# 119   data2  STGCN      X   24          64    50   0.226526  0.194404
#
#     calculation_time
# 0         550.123783
# 1         543.581154
# 2         419.522592
# 3         415.247636
# 4         422.306532
# ..               ...
# 115        428.73169
# 116       443.226369
# 117       398.531218
# 118       404.345611
# 119         413.1882
#
# [120 rows x 9 columns]

# %% [markdown]
# ### 5월 11일 50에폭 3번째 이터레이션 돌리기 시작

# %%
simul_model_50.simulation_results
# Out:
#     dataset method normal lags nof_filters epoch mse(train) mse(test)  \
# 0     data2  STGCN      X    4          16    50   0.177073  0.158718
# 1     data2  STGCN      X    4          32    50   0.188271  0.173996
# 2     data2  STGCN      X    4          64    50   0.183843  0.168644
# 3     data2  STGCN      X    8          16    50   0.192224  0.169199
# 4     data2  STGCN      X    8          32    50   0.193763  0.177408
# ..      ...    ...    ...  ...         ...   ...        ...       ...
# 115   data2  STGCN      X   12          32    50   0.209933  0.182817
# 116   data2  STGCN      X   12          64    50   0.204477  0.178089
# 117   data2  STGCN      X   24          16    50   0.214642  0.190434
# 118   data2  STGCN      X   24          32    50    0.25557  0.208072
# 119   data2  STGCN      X   24          64    50   0.353404  0.279463
#
#     calculation_time
# 0          317.86064
# 1         546.640334
# 2         473.151267
# 3         417.013636
# 4         422.140082
# ..               ...
# 115       433.280491
# 116       450.442147
# 117       400.357081
# 118       410.695924
# 119       558.969701
#
# [120 rows x 9 columns]

# %%
simul_model_50.simulation_results

# %%
plans_stgcn
# Out:
# {'max_iteration': 10,
#  'method': ['STGCN'],
#  'lags': [4, 8, 12, 24],
#  'nof_filters': [16, 32, 64],
#  'epoch': [150]}

# %%
simul_model_50.simulation_results['calculation_time'].mean()
# Out:
# 1186.3822703550259

# %%
print('stgcn ver1 50epoch 시뮬레이션 끝!')

# %% [markdown]
# - 첫번째 10iter m저장X (csv로만)
# - Dropbox/noteda/posts/SOLAR/simulation_results/2023-05-04_04-21-58.csv

# %%
import matplotlib.pyplot as plt
plt.boxplot(simul_model_50.simulation_results['mse(test)'])
plt.show()

# %% [markdown]
# ## 100 epoch

# %%
plans_stgcn = {
    'max_iteration': 10, # 30 
    'method': ['STGCN'], 
    'lags': [4, 8, 12, 24], 
    'nof_filters': [16, 32, 64], 
    'epoch': [100] # [50, 100, 150]
}

# %%
plans_stgcn
# Out:
# {'max_iteration': 10,
#  'method': ['STGCN'],
#  'lags': [4, 8, 12, 24],
#  'nof_filters': [16, 32, 64],
#  'epoch': [100]}

# %%
plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
plnr.simulate()
eptstgcn.save_data(plnr, './simul_model2/stgcn_v1/stgcn_v1_100epoch_3.pickle')
simul_model_100 = eptstgcn.load_data('./simul_model2/stgcn_v1/stgcn_v1_100epoch_3.pickle')
# Out:
# 1/10 is done
# 2/10 is done
# 100/100

# %%
simul_model_100.simulation_results
# Out:
#     dataset method normal lags nof_filters epoch mse(train) mse(test)  \
# 0     data2  STGCN      X    4          16   100   0.183406  0.169097
# 1     data2  STGCN      X    4          32   100   0.179978  0.161778
# 2     data2  STGCN      X    4          64   100   0.180906  0.164964
# 3     data2  STGCN      X    8          16   100   0.196384  0.169631
# 4     data2  STGCN      X    8          32   100   0.197595  0.174515
# ..      ...    ...    ...  ...         ...   ...        ...       ...
# 115   data2  STGCN      X   12          32   100    0.19678  0.172842
# 116   data2  STGCN      X   12          64   100   0.207231  0.178266
# 117   data2  STGCN      X   24          16   100   0.251782  0.208191
# 118   data2  STGCN      X   24          32   100   0.257983  0.220628
# 119   data2  STGCN      X   24          64   100   0.260816  0.224017
#
#     calculation_time
# 0         601.416962
# 1         687.800131
# 2         844.361361
# 3         828.892196
# 4         957.064054
# ..               ...
# 115        649.31667
# 116       657.416144
# 117       588.360123
# 118        599.18159
# 119       629.292965
#
# [120 rows x 9 columns]

# %%
simul_model_100.simulation_results
# Out:
#     dataset method normal lags nof_filters epoch mse(train) mse(test)  \
# 0     data2  STGCN      X    4          16   100   0.195067  0.180725
# 1     data2  STGCN      X    4          32   100   0.181248   0.16525
# 2     data2  STGCN      X    4          64   100   0.183541  0.165472
# 3     data2  STGCN      X    8          16   100   0.201609  0.180656
# 4     data2  STGCN      X    8          32   100   0.191182   0.17075
# ..      ...    ...    ...  ...         ...   ...        ...       ...
# 115   data2  STGCN      X   12          32   100   0.208179  0.181665
# 116   data2  STGCN      X   12          64   100   0.192994  0.168374
# 117   data2  STGCN      X   24          16   100   0.226653  0.203374
# 118   data2  STGCN      X   24          32   100    0.25733  0.219492
# 119   data2  STGCN      X   24          64   100   0.218003  0.196679
#
#     calculation_time
# 0         594.303679
# 1         611.907454
# 2         629.378186
# 3         616.519384
# 4         625.537024
# ..               ...
# 115       863.704366
# 116       894.694965
# 117       797.021305
# 118       805.615929
# 119       842.991321
#
# [120 rows x 9 columns]

# %% [markdown]
# - 여기까지 완료!

# %%
# eptstgcn.save_data(plnr, './simul_model2/stgcn_v1/stgcn_v1_100epoch.pickle')

# %%
# simul_model_100 = eptstgcn.load_data('./simul_model2/stgcn_v1/stgcn_v1_100epoch.pickle')

# %% [markdown]
# ## 150 epoch

# %%
plans_stgcn = {
    'max_iteration': 10, # 30 
    'method': ['STGCN'], 
    'lags': [4, 8, 12, 24], 
    'nof_filters': [16, 32, 64], 
    'epoch': [150] # [50, 100, 150]
}

# %%
plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
plnr.simulate()
eptstgcn.save_data(plnr,'./simul_model2/stgcn_v1/stgcn_v1_150epoch.pickle')
simul_model_150 = eptstgcn.load_data('./simul_model2/stgcn_v1/stgcn_v1_150epoch.pickle')
# Out:
# 137/150

# %%
eptstgcn.save_data(plnr,'./simul_model2/stgcn_v1/stgcn_v1_150epoch.pickle')

# %%
simul_model_150 = eptstgcn.load_data('./simul_model2/stgcn_v1/stgcn_v1_150epoch.pickle')

# %%
simul_model_150 = eptstgcn.load_data('./simul_model2/stgcn_v1/second/stgcn_v1_150epoch_2.pickle')

# %%
simul_model_150.simulation_results
# Out:
#     dataset method normal lags nof_filters epoch mse(train) mse(test)  \
# 0     data2  STGCN      X    4          16   150   0.186116  0.165823
# 1     data2  STGCN      X    4          32   150   0.185565  0.171283
# 2     data2  STGCN      X    4          64   150   0.200393  0.186591
# 3     data2  STGCN      X    8          16   150   0.198985  0.172985
# 4     data2  STGCN      X    8          32   150   0.201762  0.175557
# ..      ...    ...    ...  ...         ...   ...        ...       ...
# 235   data2  STGCN      X   12          32   150   0.189189  0.168207
# 236   data2  STGCN      X   12          64   150   0.193969  0.176804
# 237   data2  STGCN      X   24          16   150   0.220608  0.190391
# 238   data2  STGCN      X   24          32   150   0.248845   0.21056
# 239   data2  STGCN      X   24          64   150   0.216271  0.191787
#
#     calculation_time
# 0        1221.462088
# 1        1237.214506
# 2        1497.534026
# 3        1041.296445
# 4          948.47674
# ..               ...
# 235      1310.145853
# 236      1346.117926
# 237      1204.447807
# 238      1234.316041
# 239       1002.52125
#
# [240 rows x 9 columns]

# %% [markdown]
# 240개 한꺼번에 저장된 파일(second/stgcn_v1_150epoch_2) -- 2iteration
