# %% [raw]
# ---
# title: "**[SOLAR]** Dataset for STGCN Ver1 "
# author: "JiyunLim"
# date: "04/06/2023"
# categories:
#   - SOLAR
#   - Data
# ---

# %% [markdown]
# # Create dataset for STGCN Ver1

# %% [markdown]
# ## ref : [***STGCN튜토리얼***](https://miruetoto.github.io/yechan3/posts/3_Researches/ITSTGCN/2022-12-29-STGCN-tutorial.html)

# %%
# !pip install torch-geometric
# !pip install torch-geometric-temporal

# %% [markdown]
# ## import

# %% [markdown]
# `-` 필요한 패키지 임포트

# %%
import pandas as pd
import numpy as np
import json
import urllib

# %%
# 일반적인 모듈 
import numpy as np
import matplotlib.pyplot as plt 
import networkx as nx 
from tqdm import tqdm 

# 파이토치 관련 
import torch
import torch.nn.functional as F

# PyG 관련 
from torch_geometric.data import Data

# STGCN 관련 
import torch_geometric_temporal
from torch_geometric_temporal.nn.recurrent import GConvGRU
from torch_geometric_temporal.signal import temporal_signal_split

# %% [markdown]
# - `tqdm`: for문의 진행상태를 확인하기 위한 패키지
# - `networkx`: 그래프 시그널 시각화를 위한 모듈
# - `torch` : 파이토치 (STGCN은 파이토치 기반으로 만들어짐) 모듈
# - `torch.nn.functional`: relu 등의 활성화함수를 불러오기 위한 모듈
# - `Data` : 그래프 자료를 만들기 위한 클래스
# - `GConvGRU` : STGCN layer를 만드는 클래스
# - `temporal_signal_split` : STGCN dataset을 train/test 형태로 분리하는 기능이 있는 "함수"

# %% [markdown]
# `-` STGCN 학습을 위한 클래스 선언

# %%
class RecurrentGCN(torch.nn.Module):
    def __init__(self, node_features, filters):
        super(RecurrentGCN, self).__init__()
        self.recurrent = GConvGRU(node_features, filters, 2)
        self.linear = torch.nn.Linear(filters, 1)

    def forward(self, x, edge_index, edge_weight):
        h = self.recurrent(x, edge_index, edge_weight)
        h = F.relu(h)
        h = self.linear(h)
        return h

# %% [markdown]
# ## 데이터셋 만들기

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### `node id` > edges > weight > feature

# %%
url = 'https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data/df_new.csv'
df = pd.read_csv(url)

# %%
url2 = 'https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data/weight.csv'
df2 = pd.read_csv(url2)

# %%
df = df.iloc[:,1:]

# %%
node_list =(df.columns).tolist()
node_ids = {node : i for i, node in enumerate(node_list)}
node_ids
# Out:
# {'북춘천': 0,
#  '철원': 1,
#  '대관령': 2,
#  '춘천': 3,
#  '백령도': 4,
#  '북강릉': 5,
#  '강릉': 6,
#  '서울': 7,
#  '인천': 8,
#  '원주': 9,
#  '울릉도': 10,
#  '수원': 11,
#  '서산': 12,
#  '청주': 13,
#  '대전': 14,
#  '추풍령': 15,
#  '안동': 16,
#  '포항': 17,
#  '대구': 18,
#  '전주': 19,
#  '창원': 20,
#  '광주': 21,
#  '부산': 22,
#  '목포': 23,
#  '여수': 24,
#  '흑산도': 25,
#  '고창': 26,
#  '홍성': 27,
#  '제주': 28,
#  '고산': 29,
#  '진주': 30,
#  '고창군': 31,
#  '영광군': 32,
#  '김해시': 33,
#  '순창군': 34,
#  '북창원': 35,
#  '양산시': 36,
#  '보성군': 37,
#  '강진군': 38,
#  '의령군': 39,
#  '함양군': 40,
#  '광양시': 41,
#  '청송군': 42,
#  '경주시': 43}

# %%
edges = []    
 
for i in range(44):
    for j in range(44):
        if i != j:
            edges.append([i,j]) 
# print(edges)

# %%
np.array(edges).shape
# Out:
# (1892, 2)

# %%
# from itertools import permutations
# list(permutations(list(node_ids.values()), 2))

# %%
len(df['date']) # time
# Out:
# 18250

# %%
df2
# Out:
#          북춘천        철원       대관령        춘천       백령도       북강릉        강릉  \
# 0   1.000000  0.962367  0.909826  0.985657  0.871681  0.900659  0.890927
# 1   0.962367  1.000000  0.890696  0.960057  0.886264  0.884161  0.874764
# 2   0.909826  0.890696  1.000000  0.905515  0.819283  0.953088  0.947341
# 3   0.985657  0.960057  0.905515  1.000000  0.874211  0.898639  0.888139
# 4   0.871681  0.886264  0.819283  0.874211  1.000000  0.820746  0.813769
# 5   0.900659  0.884161  0.953088  0.898639  0.820746  1.000000  0.977052
# 6   0.890927  0.874764  0.947341  0.888139  0.813769  0.977052  1.000000
# 7   0.943081  0.945527  0.884961  0.943508  0.875487  0.876560  0.867627
# 8   0.936899  0.941293  0.882525  0.938434  0.898814  0.878769  0.869775
# 9   0.944473  0.930826  0.921151  0.942972  0.841837  0.908658  0.900690
# 10  0.840858  0.828910  0.858557  0.839147  0.772705  0.858164  0.848237
# 11  0.942564  0.939509  0.899435  0.943069  0.877389  0.892617  0.884630
# 12  0.922022  0.918923  0.888105  0.920695  0.882590  0.882694  0.875230
# 13  0.918237  0.905049  0.903431  0.917908  0.841079  0.896871  0.889428
# 14  0.898490  0.882652  0.891051  0.898174  0.827093  0.885413  0.878953
# 15  0.890061  0.876204  0.905452  0.890275  0.821154  0.900803  0.894228
# 16  0.903591  0.885217  0.918386  0.903755  0.825018  0.913419  0.906546
# 17  0.854662  0.838961  0.891356  0.854821  0.790609  0.891884  0.883858
# 18  0.880498  0.866139  0.900774  0.878750  0.821373  0.897400  0.888819
# 19  0.888314  0.877357  0.884532  0.887202  0.827562  0.880492  0.873037
# 20  0.860796  0.847790  0.874407  0.860170  0.808751  0.871520  0.863835
# 21  0.859424  0.852501  0.859687  0.860333  0.812785  0.856745  0.848790
# 22  0.854479  0.841909  0.871403  0.853623  0.801025  0.866994  0.858023
# 23  0.866337  0.861476  0.860613  0.867357  0.838917  0.858313  0.852067
# 24  0.857004  0.845811  0.865706  0.856728  0.817327  0.859749  0.854646
# 25  0.822826  0.822140  0.808481  0.826616  0.825401  0.811498  0.806484
# 26  0.879083  0.871026  0.865649  0.880956  0.835276  0.862511  0.855801
# 27  0.917044  0.909108  0.893061  0.918305  0.867335  0.889219  0.882249
# 28  0.797674  0.794452  0.808165  0.800473  0.787829  0.804120  0.800353
# 29  0.823267  0.821438  0.818549  0.826090  0.810675  0.812992  0.808599
# 30  0.860523  0.846942  0.877411  0.860094  0.817874  0.873037  0.866739
# 18  0.920683  0.955571  0.952851  0.935928  0.952312  0.952993
# 19  0.927649  0.919504  0.938138  0.922211  0.915050  0.894398
# 20  0.928480  0.968391  0.940725  0.952405  0.926913  0.939050
# 21  0.939738  0.917915  0.928268  0.925915  0.901910  0.889684
# 22  0.918842  0.950573  0.929205  0.939658  0.922093  0.936774
# 23  0.957647  0.922845  0.925556  0.932798  0.896801  0.887664
# 24  0.943037  0.953180  0.936996  0.965857  0.909258  0.909195
# 25  0.898532  0.869034  0.872795  0.879107  0.839579  0.837283
# 26  0.938474  0.917802  0.929699  0.923018  0.904717  0.886433
# 27  0.897861  0.891294  0.905806  0.894126  0.895564  0.868894
# 28  0.895220  0.874571  0.872941  0.878597  0.847435  0.853887
# 29  0.907588  0.883369  0.878469  0.894774  0.853910  0.852406
# 30  0.934954  0.971752  0.948990  0.961034  0.923896  0.932067
# 31  0.935929  0.914995  0.929255  0.921594  0.904133  0.886793
# 32  0.938028  0.915348  0.925572  0.921830  0.898344  0.882798
# 33  0.917226  0.956417  0.933244  0.941004  0.926691  0.944078
# 34  0.946780  0.932585  0.949482  0.938813  0.917386  0.898405
# 35  0.921424  0.962523  0.938369  0.945592  0.927509  0.944296
# 36  0.915165  0.953589  0.934088  0.937319  0.928486  0.945121
# 37  0.968149  0.948806  0.944262  0.964120  0.911247  0.908184
# 38  1.000000  0.931533  0.932621  0.947967  0.902115  0.892997
# 39  0.931533  1.000000  0.952391  0.955940  0.930412  0.940236
# 40  0.932621  0.952391  1.000000  0.942140  0.934759  0.927935
# 41  0.947967  0.955940  0.942140  1.000000  0.915408  0.914159
# 42  0.902115  0.930412  0.934759  0.915408  1.000000  0.943917
# 43  0.892997  0.940236  0.927935  0.914159  0.943917  1.000000
#
# [44 rows x 44 columns]

# %%
weights = []    
 
for i in range(44):
    for j in range(44):
        if i != j:
            weights.append(df2.iloc[i,j])

# %%
np.array(weights).shape
# Out:
# (1892,)

# %%
FX = []    
for i in range(18250):
    FX.append(list(df.iloc[i,:])) 
#FX

# %%
np.array(FX).shape
# Out:
# (18250, 44)

# %% [markdown]
# `-` weights, edges, node_ids, FX

# %%
data_dict = {'edges':edges, 'node_ids':node_ids, 'weights':weights, 'FX':FX}

# %%
data_dict.keys()
# Out:
# dict_keys(['edges', 'node_ids', 'weights', 'FX'])

# %%
file_path = './data/solar.json'

# %%
with open(file_path, 'w') as f:
    json.dump(data_dict, f)

# %%
with open(file_path, 'r') as f:
    test = json.load(f, encoding='cp949')

# %%
# json_data = json.dumps(data_dict, ensure_ascii=False)
# json_data

# %% [markdown]
# - ${\bf f}=\begin{bmatrix} {\bf f}_1\\ {\bf f}_2\\ \dots \\ {\bf f}_{521} \end{bmatrix}=\begin{bmatrix} f(t=1,v=\tt{BACS}) & \dots & f(t=1,v=\tt{ZALA}) \\ f(t=2,v=\tt{BACS}) & \dots & f(t=2,v=\tt{ZALA}) \\ \dots & \dots & \dots \\ f(t=521,v=\tt{BACS}) & \dots & f(t=521,v=\tt{ZALA}) \end{bmatrix}$
