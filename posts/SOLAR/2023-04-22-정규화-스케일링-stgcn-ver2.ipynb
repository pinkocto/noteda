# %% [raw]
# ---
# title: " **[SOLAR]** STGCN Ver2 (data2, +N +S) 30회"
# author: "JiyunLim"
# date: "04/22/2023"
# categories:
#   - Research
#   - STGCN
#   - SOLAR
# ---

# %% [markdown]
# # STGCN Ver2

# %% [markdown]
# ## ref
# - <https://github.com/miruetoto/yechan3/tree/main/posts/3_Researches/ITSTGCN/itstgcn>
# - <https://miruetoto.github.io/yechan3/posts/3_Researches/ITSTGCN/2023-03-18-SimulationPlanner-Tutorial.html#plnr_gnar_block>

# %% [markdown]
# ## 2022/06/01 ~ 2022/09/15
#
# - train 2022-06-01 00:00:00 ~ 2022-08-14 17:00:00
# - test 2022-08-14 18:00:00 ~ 2022-09-15 23:00:00

# %% [markdown]
# ## Import

# %%
import eptstgcn
import torch
import eptstgcn.planner

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
url = "https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data2/stgcn_data2.json"
loader = eptstgcn.DatasetLoader(url)
dataset = loader.get_dataset(lags=4)

# %%
train_dataset, test_dataset = eptstgcn.utils.temporal_signal_split(dataset, train_ratio = 0.7)

# %% [markdown]
# ## LRNR

# %% [markdown]
# - ref: <https://seoyeonc.github.io/blog/posts/GCN/2023-03-17-ITSTGCN-Tutorial.html>

# %%
lrnr = eptstgcn.StgcnLearner(train_dataset, dataset_name = 'data2(2022/06/01 ~ 2022/09/15)')

# %%
lrnr.learn(filters=32, epoch=50)
# Out:
# 50/50

# %%
# import pickle 
# with open('./lrnr_model/stgcn_ver2_data2.pickle','wb') as fw:
#     pickle.dump(lrnr, fw)

# %%
import pickle 
with open('./lrnr_model/stgcn_ver2_data2.pickle', 'rb') as f: 
    model = pickle.load(f)

# %% [markdown]
# ## Visualization

# %%
evtor = eptstgcn.Evaluator(model, train_dataset, test_dataset)

# %%
# fig = evtor.plot('--', label='observed data')
# fig.tight_layout()
# fig

# %% [markdown]
# ### train

# %%
evtor.tr_plot(t=150, label='observed data')

# %% [markdown]
# ### test

# %%
evtor.test_plot(t=150, label='observed data')

# %% [markdown]
# ## Simulation

# %%
plans_stgcn = {
    'max_iteration': 30, 
    'method': ['EPT-STGCN'], 
    'lags': [4], 
    'nof_filters': [32], 
    'epoch': [50]
}

# %%
# plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
# plnr.simulate()
# Out:
# 1/30 is done
# 2/30 is done
# 3/30 is done
# 4/30 is done
# 5/30 is done
# 6/30 is done
# 7/30 is done
# 8/30 is done
# 9/30 is done
# 10/30 is done
# 11/30 is done
# 12/30 is done
# 13/30 is done
# 14/30 is done
# 15/30 is done
# 16/30 is done
# 17/30 is done
# 18/30 is done
# 19/30 is done
# 20/30 is done
# 21/30 is done
# 22/30 is done
# 23/30 is done
# 24/30 is done
# 25/30 is done
# 26/30 is done
# 27/30 is done
# 28/30 is done
# 29/30 is done
# 30/30 is done
# All results are stored in ./simulation_results/2023-04-22_14-25-52.csv

# %%
# import pickle
# with open('./simul_model/stgcn_ver2_data2.pickle', 'wb') as fw:
#     pickle.dump(plnr, fw)

# %%
with open('./simul_model/stgcn_ver2_data2.pickle', 'rb') as f:
    simul_model = pickle.load(f)

# %%
df_simul = simul_model.simulation_results
df_simul
# Out:
#    dataset     method lags nof_filters epoch mse(train) mse(test)  \
# 0    data2  EPT-STGCN    4          32    50   0.191743  0.174037
# 1    data2  EPT-STGCN    4          32    50   0.188173  0.171402
# 2    data2  EPT-STGCN    4          32    50   0.193801  0.177204
# 3    data2  EPT-STGCN    4          32    50   0.193846  0.177513
# 4    data2  EPT-STGCN    4          32    50   0.192977  0.172927
# 5    data2  EPT-STGCN    4          32    50   0.192712  0.176857
# 6    data2  EPT-STGCN    4          32    50   0.195432  0.179403
# 7    data2  EPT-STGCN    4          32    50   0.193558   0.17668
# 8    data2  EPT-STGCN    4          32    50   0.188431  0.170934
# 9    data2  EPT-STGCN    4          32    50   0.194312  0.178338
# 10   data2  EPT-STGCN    4          32    50   0.192146   0.17524
# 11   data2  EPT-STGCN    4          32    50    0.21723  0.202964
# 12   data2  EPT-STGCN    4          32    50   0.191419  0.175272
# 13   data2  EPT-STGCN    4          32    50   0.189603   0.16854
# 14   data2  EPT-STGCN    4          32    50   0.192472  0.175902
# 15   data2  EPT-STGCN    4          32    50   0.195813  0.180936
# 16   data2  EPT-STGCN    4          32    50   0.192051  0.172564
# 17   data2  EPT-STGCN    4          32    50   0.186588  0.169016
# 18   data2  EPT-STGCN    4          32    50   0.188448   0.17067
# 19   data2  EPT-STGCN    4          32    50   0.192218  0.174493
# 20   data2  EPT-STGCN    4          32    50   0.194702  0.178929
# 21   data2  EPT-STGCN    4          32    50   0.191139  0.171002
# 22   data2  EPT-STGCN    4          32    50   0.193083  0.176349
# 23   data2  EPT-STGCN    4          32    50   0.188758  0.168046
# 24   data2  EPT-STGCN    4          32    50   0.193287  0.176689
# 25   data2  EPT-STGCN    4          32    50   0.196557  0.182426
# 26   data2  EPT-STGCN    4          32    50   0.197129   0.17901
# 27   data2  EPT-STGCN    4          32    50   0.188209  0.170222
# 28   data2  EPT-STGCN    4          32    50    0.19453   0.17823
# 29   data2  EPT-STGCN    4          32    50   0.194562  0.178458
#
#    calculation_time
# 0        308.999537
# 1        310.277773
# 2        308.135715
# 3        307.202175
# 4        301.829093
# 5        301.443737
# 6        303.030302
# 7        302.182927
# 8        300.978617
# 9        301.406438
# 10       310.645684
# 11       309.016529
# 12       301.719725
# 13       298.208967
# 14       298.160489
# 15       298.502372
# 16       303.121567
# 17       298.217363
# 18       308.988231
# 19       314.624435
# 20       312.727251
# 21        307.64198
# 22       308.692932
# 23       298.516863
# 24       300.613522
# 25       300.518729
# 26       303.639919
# 27       305.739781
# 28       316.576063
# 29       304.878169

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_simul['mse(test)'])
plt.show()
