# %% [raw]
# ---
# title: " **[SOLAR]** STGCN Ver2 (data2, -N +S) 시뮬레이션 (epoch, filter, lag)"
# author: "JiyunLim"
# date: "05/03/2023"
# categories:
#   - Research
#   - STGCN
#   - SOLAR
# ---

# %% [markdown]
# # STGCN Ver2 (EPT-STGCN)

# %% [markdown]
# > 10 iter, 50에폭 돌아가는중 (05-04 밤 start) // 완료!
#
# > 10 iter, 100에폭 돌아가는중 (05-06 오전 11시 57분 start) // 완료! --> 모델 날라감.
#
# > 10 iter, 150에폭 돌아가는중 (05-07 오후2시 32분 start) // 완료! (5월 9일 오전 10시)

# %% [markdown]
# ***10iter 완료***

# %% [markdown]
# > 10 iter, 50에폭 돌리기 (진행중)

# %% [markdown]
# ## ref
# - <https://github.com/miruetoto/yechan3/tree/main/posts/3_Researches/ITSTGCN/itstgcn>
# - <https://miruetoto.github.io/yechan3/posts/3_Researches/ITSTGCN/2023-03-18-SimulationPlanner-Tutorial.html#plnr_gnar_block>

# %% [markdown]
# ## 2022/06/01 ~ 2022/09/15
#
# - train 2022-06-01 00:00:00 ~ 2022-08-14 17:00:00
# - test 2022-08-14 18:00:00 ~ 2022-09-15 23:00:00

# %% [markdown]
# # Import

# %%
import eptstgcn
import torch
import eptstgcn.planner

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read Data

# %%
url = "https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data2/stgcn_data2.json"
loader = eptstgcn.DatasetLoader(url)
# dataset = loader.get_dataset(lags=4)
# train_dataset, test_dataset = eptstgcn.utils.temporal_signal_split(dataset, train_ratio = 0.7)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## 50 epoch

# %%
plans_stgcn = {
    'max_iteration': 10,   # 30, 
    'method': ['EPT-STGCN'], 
    'lags': [4, 8, 12, 24],  # [4, 8, 12]
    'nof_filters': [16, 32, 64], # [16, 32, 64]
    'epoch': [50] # [50, 100, 150]
}

# %%
plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
plnr.simulate()
eptstgcn.save_data(plnr, './simul_model2/stgcn_v2/second/stgcn_v2_50epoch.pickle')
simul_model = eptstgcn.load_data('./simul_model2/stgcn_v2/second/stgcn_v2_50epoch.pickle')
# Out:
# 1/50

# %%
# eptstgcn.save_data(plnr, './simul_model2/stgcn_v2/stgcn_v2_50epoch.pickle')

# %%
# simul_model = eptstgcn.load_data('./simul_model2/stgcn_v2/stgcn_v2_50epoch.pickle')

# %%
df_simul_no = simul_model.simulation_results
df_simul_no
# Out:
#     dataset     method normal lags nof_filters epoch mse(train) mse(test)  \
# 0     data2  EPT-STGCN    NaN    4          16    50   0.192152  0.173403
# 1     data2  EPT-STGCN    NaN    4          32    50   0.184834  0.166629
# 2     data2  EPT-STGCN    NaN    4          64    50   0.186183  0.169907
# 3     data2  EPT-STGCN    NaN    8          16    50   0.200127  0.171658
# 4     data2  EPT-STGCN    NaN    8          32    50   0.203025   0.17327
# ..      ...        ...    ...  ...         ...   ...        ...       ...
# 115   data2  EPT-STGCN    NaN   12          32    50   0.198326  0.183998
# 116   data2  EPT-STGCN    NaN   12          64    50   0.200407  0.173493
# 117   data2  EPT-STGCN    NaN   24          16    50   0.311627   0.25768
# 118   data2  EPT-STGCN    NaN   24          32    50    0.25655  0.213685
# 119   data2  EPT-STGCN    NaN   24          64    50    0.25666  0.207781
#
#     calculation_time
# 0         430.805053
# 1         553.995057
# 2         568.342531
# 3         484.037182
# 4         416.375737
# ..               ...
# 115       431.555464
# 116       444.294899
# 117       403.552449
# 118       539.358858
# 119       562.105567
#
# [120 rows x 9 columns]

# %%
# df_simul_no = simul_model.simulation_results
# df_simul_no

# %% [markdown]
# ## 100epoch

# %%
plans_stgcn = {
    'max_iteration': 10,   # 30, 
    'method': ['EPT-STGCN'], 
    'lags': [4, 8, 12, 24],  # [4, 8, 12]
    'nof_filters': [16, 32, 64], # [16, 32, 64]
    'epoch': [100] # [50, 100, 150]
}

# %%
plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
plnr.simulate()
eptstgcn.save_data(plnr,'./simul_model2/stgcn_v2/stgcn_v2_100epoch.pickle')
simul_model_100 = eptstgcn.load_data('./simul_model2/stgcn_v2/stgcn_v2_100epoch.pickle')
# Out:
# 1/10 is done
# 2/10 is done
# 3/10 is done
# 4/10 is done
# 24/1000

# %%
simul_model_100.simulation_results
# Out:
#     dataset     method normal lags nof_filters epoch mse(train) mse(test)  \
# 0     data2  EPT-STGCN    NaN    4          16   100   0.192383   0.17238
# 1     data2  EPT-STGCN    NaN    4          32   100   0.182036  0.162083
# 2     data2  EPT-STGCN    NaN    4          64   100   0.182569  0.163465
# 3     data2  EPT-STGCN    NaN    8          16   100   0.192919  0.168806
# 4     data2  EPT-STGCN    NaN    8          32   100   0.199459   0.17362
# ..      ...        ...    ...  ...         ...   ...        ...       ...
# 115   data2  EPT-STGCN    NaN   12          32   100   0.201038  0.179846
# 116   data2  EPT-STGCN    NaN   12          64   100   0.200569  0.172256
# 117   data2  EPT-STGCN    NaN   24          16   100   0.250253  0.199742
# 118   data2  EPT-STGCN    NaN   24          32   100   0.223538  0.195406
# 119   data2  EPT-STGCN    NaN   24          64   100    0.23775  0.209232
#
#     calculation_time
# 0        1095.311545
# 1        1117.031205
# 2        1141.591372
# 3          919.13007
# 4         839.538126
# ..               ...
# 115       634.851532
# 116       660.412136
# 117       594.428839
# 118       601.475364
# 119       630.741058
#
# [120 rows x 9 columns]

# %%
print('끝났따! ㅎㅎ')
# Out:
# 끝났따! ㅎㅎ

# %% [markdown]
# ## 150epoch

# %%
plans_stgcn = {
    'max_iteration': 10,   # 30, 
    'method': ['EPT-STGCN'], 
    'lags': [4, 8, 12, 24],  # [4, 8, 12]
    'nof_filters': [16, 32, 64], # [16, 32, 64]
    'epoch': [150] # [50, 100, 150]
}

# %%
plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
plnr.simulate()
eptstgcn.save_data(plnr,'./simul_model2/stgcn_v2/stgcn_v2_150epoch.pickle')
simul_model_150 = eptstgcn.load_data('./simul_model2/stgcn_v2/stgcn_v2_150epoch.pickle')
# Out:
# 1/10 is done
# 103/150

# %%
simul_model_150.simulation_results
# Out:
#   dataset     method normal lags nof_filters epoch mse(train) mse(test)  \
# 0   data2  EPT-STGCN      X    4          16   150   0.189039   0.16644
# 1   data2  EPT-STGCN      X    4          32   150     0.1839  0.163163
# 2   data2  EPT-STGCN      X    4          64   150   0.188576   0.16788
# 3   data2  EPT-STGCN      X    8          16   150   0.191546  0.163098
# 4   data2  EPT-STGCN      X    8          32   150   0.196264  0.171726
# 5   data2  EPT-STGCN      X    8          64   150   0.193626  0.169606
# 6   data2  EPT-STGCN      X   12          16   150   0.196048   0.16558
# 7   data2  EPT-STGCN      X   12          32   150   0.196824  0.174657
# 8   data2  EPT-STGCN      X   12          64   150   0.223708   0.18818
#
#   calculation_time
# 0       890.523769
# 1       901.624805
# 2       930.632719
# 3       922.549719
# 4       934.935377
# 5        971.07701
# 6       946.160373
# 7       953.823792
# 8       991.851157

# %%
simul_model_150.simulation_results
# Out:
#     dataset     method normal lags nof_filters epoch mse(train) mse(test)  \
# 0     data2  EPT-STGCN    NaN    4          16   150   0.192811  0.172286
# 1     data2  EPT-STGCN    NaN    4          32   150   0.196971  0.180187
# 2     data2  EPT-STGCN    NaN    4          64   150   0.180952  0.160223
# 3     data2  EPT-STGCN    NaN    8          16   150   0.206765   0.17639
# 4     data2  EPT-STGCN    NaN    8          32   150   0.196287  0.171737
# ..      ...        ...    ...  ...         ...   ...        ...       ...
# 115   data2  EPT-STGCN    NaN   12          32   150   0.196776  0.173983
# 116   data2  EPT-STGCN    NaN   12          64   150   0.197882  0.170004
# 117   data2  EPT-STGCN    NaN   24          16   150   0.222497  0.188107
# 118   data2  EPT-STGCN    NaN   24          32   150    0.25576  0.204602
# 119   data2  EPT-STGCN    NaN   24          64   150   0.222175  0.188326
#
#     calculation_time
# 0        1107.788696
# 1         1221.65175
# 2        1700.991477
# 3        1684.464239
# 4        1695.175945
# ..               ...
# 115      1290.014739
# 116      1347.436289
# 117      1199.523731
# 118      1231.037348
# 119      1288.791447
#
# [120 rows x 9 columns]

# %%
print('stgcn ver2 150epoch 시뮬레이션 끄읕!^^')
# Out:
# stgcn ver2 150epoch 시뮬레이션 끄읕!^^

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_simul_no['mse(test)'])
plt.show()

# %%
simul_model = eptstgcn.load_data('./simul_model2/stgcn_v2/stgcn_v2_100epoch.pickle')

# %%
simul_model.simulation_results
# Out:
#     dataset     method normal lags nof_filters epoch mse(train) mse(test)  \
# 0     data2  EPT-STGCN    NaN    4          16   150   0.192811  0.172286
# 1     data2  EPT-STGCN    NaN    4          32   150   0.196971  0.180187
# 2     data2  EPT-STGCN    NaN    4          64   150   0.180952  0.160223
# 3     data2  EPT-STGCN    NaN    8          16   150   0.206765   0.17639
# 4     data2  EPT-STGCN    NaN    8          32   150   0.196287  0.171737
# ..      ...        ...    ...  ...         ...   ...        ...       ...
# 115   data2  EPT-STGCN    NaN   12          32   150   0.196776  0.173983
# 116   data2  EPT-STGCN    NaN   12          64   150   0.197882  0.170004
# 117   data2  EPT-STGCN    NaN   24          16   150   0.222497  0.188107
# 118   data2  EPT-STGCN    NaN   24          32   150    0.25576  0.204602
# 119   data2  EPT-STGCN    NaN   24          64   150   0.222175  0.188326
#
#     calculation_time
# 0        1107.788696
# 1         1221.65175
# 2        1700.991477
# 3        1684.464239
# 4        1695.175945
# ..               ...
# 115      1290.014739
# 116      1347.436289
# 117      1199.523731
# 118      1231.037348
# 119      1288.791447
#
# [120 rows x 9 columns]
