# %% [raw]
# ---
# title: "**[SOLAR]** 0508 정리중"
# author: "JiyunLim"
# date: "05/08/2023"
# categories:
#   - Research
#   - STGCN
#   - SOLAR
# ---

# %% [markdown]
# - author's code repo: <https://github.com/VeritasYin/STGCN_IJCAI-18>
# - pytorch : <https://github.com/dmlc/dgl/tree/master/examples/pytorch/stgcn_wave>

# %% [markdown]
# - <https://arxiv.org/abs/1906.00121>

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Review of Existing Studies

# %% [markdown]
# STGCN: Spatio-Temporal Graph Convolutional Networks: A Deep Learning Framework for Traffic Forecasting 논문에서 시/공간을 고려하는 gcn 모델로 처음 제안된 방법론 (2018년 Yu와 Yin, Zhu가 제안한 모델)

# %% [markdown]
# ![Spatio-Temporal Graph Convolutional Networks: A Deep Learning Framework for Traffic Forecasting_2018(IJCAI) cited : 2290
# ](attachment:45a44032-d088-410d-86aa-32f2dfee418b.png)

# %% [markdown]
# [Figure1] Graph-structured traffic data. Each $v_t$ indicates a frame of current traffic status at time step $t$, which is recorded in a graph-structured data matrix

# %% [markdown]
# 입력 데이터는 시간 경과에 따라 촬용동니 도로 구간 교통정보 관련 스냅샷과 도로망 그래프로 구성.

# %% [markdown]
# 공간적 측면과 시간적 측면은 '샌드위치' 로 묘사되는 방식으로 결합된다. (Temporal  사이에  시간적 특징을 추출하는 첫번째 레이어가 공간적 특징을 추출하는 두 번째 레이어로 전달된다. 그리고 이 레이터는 또 다른 시간 레이어로 전달되는 것이다.

# %% [markdown]
# ## Proposed Method

# %% [markdown]
# > STGCN + EPT weights

# %% [markdown]
# STGCN Adjacency matrix에 지역별 일사량 ept correlation을 가중치로 준것.

# %% [markdown]
# EPT: the ensemble process makes it possible to design various filters, icluding nonlinear filters, which are suitable for extracting some meaningful features such as global trend, volatility, seasonality, and intervention.

# %% [markdown]
# - 기존 weight : $W_{ij}$
#
# - ARIMA 등 기존모델의 한계점을 언급하면서, Time과 Spatial 방법을 모두 고려한 모델들 소개.
#
#
# - Multi scale (ept 언급 꼭 안해도 됨)

# %% [markdown]
# ## Experiments

# %% [markdown]
# > [SOLAR DATA 정리](https://pinkocto.github.io/noteda/posts/SOLAR/2023-05-01-%EC%B0%A8%EC%9B%90%EC%A1%B0%EC%82%AC.html#%EB%B0%A9%EB%B2%951-staticgraphtemporalsignal-%EB%A5%BC-%EC%9D%B4%EC%9A%A9%ED%95%98%EC%97%AC-%EB%8D%B0%EC%9D%B4%ED%84%B0-%EC%85%8B-%EB%A7%8C%EB%93%A4%EA%B8%B0)

# %% [markdown]
# In this example, we analyze the soloar radiation data that were hourly observed at 44 cities in South Korea^["Bukchuncheon", "Cheolwon", "Daegwanryeong", "Chuncheon", "Baeknyeongdo", "Bukgangneung", "Gangneung", "Seoul", "Incheon", "Wonju",
# "Ulleungdo", "Suwon", "Seosan", "Cheongju", "Daejeon", "Chupungryeong", "Andong", "Pohang", "Daegu", "Jeonju", "Changwon",
# "Gwangju", "Busan", "Mokpo", "Yeosu", "Heuksando", "Gochang", "Hongseong", "Jeju", "Gosan", "Jinju", "Gochang-gun",
# Yeonggwang-gun, Gimhae-si, Sunchang-gun, Bukchang-won, Yangsan-si, Boseong-gun, Gangjin-gun, Uiryeong-gun, Hamyang-gun,
# "Gwangyang-si", "Cheongsong-gun", "Gyeongju-si"] for about four months from June 1, 2022 to September 15, 2022.

# %% [markdown]
# | **수학기호** | **코드에 저장된 변수** | **자료형** | **차원** | **설명** |
# |--------------|----------------------|------------|----------|---------|
# |${\cal V}$|`data_dict['node_ids']`|dict|44|44개의 노드에 대한 설명이 있음|
# |${\cal E}$|`data_dict['edges']`|list(double list)|(1892, 2)|노드들에 대한 1892개의 연결을 정의함|
# |${\mathbf f}$|`data_dict['FX']`|list(double list)|(2568,44)|$v \in {\cal V}$ for $v\in{\cal V}$and $t=1,\dots,T$|

# %% [markdown]
# - ${\bf f}=\begin{bmatrix} {\bf f}_1\\ {\bf f}_2\\ \dots \\ {\bf f}_{2568} \end{bmatrix}=\begin{bmatrix} f(t=1,v=\tt{북춘천}) & \dots & f(t=1,v=\tt{경주시}) \\ f(t=2,v=\tt{북춘천}) & \dots & f(t=2,v=\tt{경주시}) \\ \dots & \dots & \dots \\ f(t=2568,v=\tt{북춘천}) & \dots & f(t=2568,v=\tt{경주시}) \end{bmatrix}$

# %% [markdown]
# - no weights >> X
# - correlation by region
# - ept correlation

# %% [markdown]
# `-` weights

# %% [markdown]
# The standard time interval in dataset is set to 1 hour.
# In SOLAR, the adjacency matrix of the ??graph is computed based on the correlation coefficient among solar radiation observed in 44 cities, including Bukchunchueon, Cheolwon, etc.

# %% [markdown]
# - $(t, X_t)$ : observation at time step $t$.
# - $\cal\gamma$: scale factor
# - $U_t^\tau(X_t)$: upper envelope of ensemble path transform for size parameter $\tau$

# %% [markdown]
# $U_t^\tau(X_t) = \underset{k\in[-\tau/2, \tau/2]}{\max}\{X_{t+k}\}-0.5\cal \gamma \tau$

# %% [markdown]
# The weighted adjacency matrix $W$ can be formed as,

# %% [markdown]
# $w_{ij} = \begin{cases}  \\ 0 & ,\text{otherwise}\end{cases}$

# %% [markdown]
# where $w_{ij}$ is the weight of edge which is decided by ept correlation (the ept correlation between 44 cities)

# %% [markdown]
# **correlation by region**

# %% [markdown]
# Hourly solar radiation of observatories from South Korean  for 4 months. Vertices represent 44 cities and the weighted edges represent the strength of the relationship. The target variable allows regression operations. (The weight is the correlation coefficient of solar radiation by region.)

# %% [markdown]
# **ept correlation**

# %% [markdown]
# Hourly solar radiation of observatories from South Korean  for 4 months. Vertices represent 44 cities and the weighted edges represent the strength of the relationship. The target variable allows regression operations. The weight is the EPT correlation coefficient of solar radiation by region

# %% [markdown]
# ## 10 iter rslt (X)

# %%
import pandas as pd
import numpy as np

# %%
v1_50 = pd.read_csv('./simulation_results/A/stgcn/50.csv')
v1_100 = pd.read_csv('./simulation_results/A/stgcn/100.csv')
v1_150 = pd.read_csv('./simulation_results/A/stgcn/150.csv')

# %%
v1 = pd.concat([v1_50, v1_100, v1_150])
v1
# Out:
#     dataset method normal  lags  nof_filters  epoch  mse(train)  mse(test)  \
# 0     data2  STGCN      X     4           16     50    0.184666   0.168772
# 1     data2  STGCN      X     4           32     50    0.184967   0.170560
# 2     data2  STGCN      X     4           64     50    0.183801   0.169246
# 3     data2  STGCN      X     8           16     50    0.189229   0.165215
# 4     data2  STGCN      X     8           32     50    0.193490   0.167097
# ..      ...    ...    ...   ...          ...    ...         ...        ...
# 115   data2  STGCN      X    12           32    150    0.201391   0.177662
# 116   data2  STGCN      X    12           64    150    0.188375   0.165186
# 117   data2  STGCN      X    24           16    150    0.225323   0.195045
# 118   data2  STGCN      X    24           32    150    0.217955   0.194223
# 119   data2  STGCN      X    24           64    150    0.227995   0.206702
#
#      calculation_time
# 0          298.709778
# 1          302.935171
# 2          315.828636
# 3          309.634520
# 4          311.973553
# ..                ...
# 115       1306.056505
# 116       1348.935959
# 117       1199.328551
# 118       1223.021271
# 119       1302.931912
#
# [360 rows x 9 columns]

# %%
v2_50 = pd.read_csv('./simulation_results/A/eptstgcn/50.csv')
v2_100 = pd.read_csv('./simulation_results/A/eptstgcn/100.csv')
v2_150 = pd.read_csv('./simulation_results/A/eptstgcn/150.csv')

# %%
v2 = pd.concat([v2_50, v2_100, v2_150])
v2
# Out:
#     dataset     method  normal  lags  nof_filters  epoch  mse(train)  \
# 0     data2  EPT-STGCN     NaN     4           16     50    0.192152
# 1     data2  EPT-STGCN     NaN     4           32     50    0.184834
# 2     data2  EPT-STGCN     NaN     4           64     50    0.186183
# 3     data2  EPT-STGCN     NaN     8           16     50    0.200127
# 4     data2  EPT-STGCN     NaN     8           32     50    0.203025
# ..      ...        ...     ...   ...          ...    ...         ...
# 115   data2  EPT-STGCN     NaN    12           32    150    0.196776
# 116   data2  EPT-STGCN     NaN    12           64    150    0.197882
# 117   data2  EPT-STGCN     NaN    24           16    150    0.222497
# 118   data2  EPT-STGCN     NaN    24           32    150    0.255760
# 119   data2  EPT-STGCN     NaN    24           64    150    0.222175
#
#      mse(test)  calculation_time
# 0     0.173403        430.805053
# 1     0.166629        553.995057
# 2     0.169907        568.342531
# 3     0.171658        484.037182
# 4     0.173270        416.375737
# ..         ...               ...
# 115   0.173983       1290.014739
# 116   0.170004       1347.436289
# 117   0.188107       1199.523731
# 118   0.204602       1231.037348
# 119   0.188326       1288.791447
#
# [360 rows x 9 columns]

# %% [markdown]
# # SIMUL RLST (EDIT)

# %% [markdown]
# - 50에폭 >> 9시간 정도
# - 100에폭 >> 20시간

# %%
import eptstgcn
import torch
import pandas as pd
import numpy as np
import gc

# %%
gc.collect()
# Out:
# 0

# %%
path1 = './simul_model3/stgcn_v1/stgcn_v1_'
v1_50 = eptstgcn.load_data(path1 + '50epoch_1.pickle').simulation_results
v1_100 = eptstgcn.load_data(path1 + '100epoch_1.pickle').simulation_results
v1_150 = eptstgcn.load_data(path1 + '150epoch_1.pickle').simulation_results

# %%
path2 = './simul_model3/stgcn_v2/stgcn_v2_'
v2_50 = eptstgcn.load_data(path2 + '50epoch_1.pickle').simulation_results
v2_100 = eptstgcn.load_data(path2 + '100epoch_1.pickle').simulation_results
v2_150 = eptstgcn.load_data(path2 + '150epoch_1.pickle').simulation_results

# %%
import seaborn as sns

# %%
v2_50.head()
# Out:
#   dataset     method lags nof_filters epoch mse(train) mse(test)  \
# 0   data4  EPT-STGCN    4          16    50   0.084629  0.061934
# 1   data4  EPT-STGCN    4          32    50   0.085535  0.062247
# 2   data4  EPT-STGCN    4          64    50   0.084318  0.062279
# 3   data4  EPT-STGCN    8          16    50   0.089842  0.062246
# 4   data4  EPT-STGCN    8          32    50   0.091354  0.064101
#
#   calculation_time
# 0       377.073909
# 1       379.226406
# 2       390.993526
# 3       385.108667
# 4       390.866865

# %% [markdown]
# ### 50 epoch

# %% [markdown]
# `-` VER1

# %%
v1_50.groupby(["lags","nof_filters"])\
.agg({"mse(train)":["mean","median","var"], "mse(test)":["mean","median","var"],'calculation_time':['sum','mean']})
# Out:
#                  mse(train)                     mse(test)                      \
#                        mean    median       var      mean    median       var
# lags nof_filters
# 4    16            0.084270  0.084499  0.000004  0.059484  0.059176  0.000003
#      32            0.084037  0.083453  0.000007  0.059276  0.058487  0.000004
#      64            0.084179  0.083638  0.000008  0.059523  0.059032  0.000007
# 8    16            0.088851  0.088984  0.000005  0.062446  0.061876  0.000006
#      32            0.087715  0.087310  0.000004  0.061116  0.060672  0.000003
#      64            0.087992  0.087578  0.000004  0.061215  0.061034  0.000006
# 12   16            0.092746  0.092524  0.000015  0.062373  0.061873  0.000003
#      32            0.091739  0.090830  0.000017  0.062214  0.061929  0.000005
#      64            0.089954  0.089078  0.000013  0.061142  0.060941  0.000002
#
#                  calculation_time
#                               sum        mean
# lags nof_filters
# 4    16               3997.182283  399.718228
#      32               4085.178453  408.517845
#      64               4199.614521  419.961452
# 8    16               4181.235220  418.123522
#      32               4242.822857  424.282286
#      64               4482.406707  448.240671
# 12   16               4178.229441  417.822944
#      32               4180.369672  418.036967
#      64               4312.241898  431.224190

# %% [markdown]
# `-` VER2

# %%
v2_50.groupby(["lags","nof_filters"])\
.agg({"mse(train)":["mean","median","var"],"mse(test)":["mean","median","var"],'calculation_time':['sum','mean']})
# Out:
#                  mse(train)                     mse(test)            \
#                        mean    median       var      mean    median
# lags nof_filters
# 4    16            0.085533  0.085274  0.000003  0.062547  0.062579
#      32            0.085785  0.085591  0.000002  0.062446  0.062199
#      64            0.085988  0.086066  0.000004  0.062559  0.062754
# 8    16            0.095805  0.094245  0.000038  0.066146  0.064537
#      32            0.092812  0.092827  0.000003  0.063727  0.063922
#      64            0.093753  0.094034  0.000003  0.064316  0.063953
# 12   16            0.100330  0.100233  0.000024  0.065345  0.065215
#      32            0.097618  0.096437  0.000016  0.064290  0.063862
#      64            0.098199  0.097655  0.000010  0.065173  0.064954
#
#                                calculation_time
#                            var              sum        mean
# lags nof_filters
# 4    16           1.590308e-06      3743.159758  374.315976
#      32           2.646364e-06      3781.962565  378.196256
#      64           1.753533e-06      3891.303296  389.130330
# 8    16           2.733121e-05      3931.576383  393.157638
#      32           7.007360e-07      4004.900508  400.490051
#      64           1.663501e-06      4253.729333  425.372933
# 12   16           4.141794e-06      4084.487549  408.448755
#      32           3.252359e-06      3963.308064  396.330806
#      64           2.429024e-06      4073.584253  407.358425

# %% [markdown]
# - 50epoch일때, lag기준으로 lag=4일때가 가장 좋으며, 그 중 filter=32일때가 best.
# - 전체적으로 너무 잘맞춘다..

# %% [markdown]
# ## 100 epoch

# %% [markdown]
# `-` VER1

# %%
v1_100.groupby(['lags','nof_filters'])\
.agg({'mse(train)':['mean','median','var'],'mse(test)':['mean','median','var'],'calculation_time':['sum','mean']})
# Out:
#                  mse(train)                     mse(test)                      \
#                        mean    median       var      mean    median       var
# lags nof_filters
# 4    16            0.084707  0.084580  0.000007  0.059889  0.060103  0.000002
#      32            0.082834  0.083203  0.000003  0.058977  0.059389  0.000002
#      64            0.081672  0.081013  0.000004  0.057895  0.057559  0.000002
# 8    16            0.087643  0.087989  0.000002  0.062011  0.061883  0.000003
#      32            0.087600  0.087028  0.000005  0.061221  0.061124  0.000001
#      64            0.087036  0.086683  0.000006  0.061109  0.060445  0.000005
# 12   16            0.091386  0.090597  0.000028  0.062143  0.062132  0.000003
#      32            0.091917  0.092822  0.000022  0.062013  0.061270  0.000007
#      64            0.088291  0.087355  0.000008  0.060873  0.060599  0.000003
#
#                  calculation_time
#                               sum        mean
# lags nof_filters
# 4    16               8330.884841  833.088484
#      32               8644.790288  864.479029
#      64               8570.456837  857.045684
# 8    16               8204.451093  820.445109
#      32               8228.373266  822.837327
#      64               8667.659043  866.765904
# 12   16               8526.771408  852.677141
#      32               8647.877128  864.787713
#      64               8951.653593  895.165359

# %% [markdown]
# - ver1의 경우 필터의 수가 많아질 수록 성능 좋아짐.

# %% [markdown]
# `-` VER2

# %%
v2_100.groupby(['lags','nof_filters'])\
.agg({'mse(train)':['mean','median','var'],'mse(test)':['mean','median','var'],'calculation_time':['sum','mean']})
# Out:
#                  mse(train)                         mse(test)            \
#                        mean    median           var      mean    median
# lags nof_filters
# 4    16            0.085489  0.085402  1.247371e-06  0.062209  0.061615
#      32            0.086252  0.086306  3.191599e-06  0.062746  0.062383
#      64            0.085022  0.084889  1.931205e-06  0.061806  0.061519
# 8    16            0.094756  0.094076  2.208262e-05  0.064861  0.064554
#      32            0.092870  0.092729  5.922879e-06  0.063626  0.063464
#      64            0.089127  0.088799  9.973435e-07  0.062611  0.062528
# 12   16            0.096523  0.096394  1.852449e-05  0.064712  0.064234
#      32            0.097790  0.095919  2.683867e-05  0.065321  0.064057
#      64            0.097300  0.095383  3.902691e-05  0.066048  0.064520
#
#                                calculation_time
#                            var              sum        mean
# lags nof_filters
# 4    16           1.751449e-06      7681.955477  768.195548
#      32           2.374723e-06      7781.321143  778.132114
#      64           1.434596e-06      8038.013325  803.801333
# 8    16           4.653744e-06      7944.524897  794.452490
#      32           9.076257e-07      7908.120206  790.812021
#      64           3.762621e-07      8079.185016  807.918502
# 12   16           6.236064e-06      8208.384458  820.838446
#      32           8.763479e-06      8328.022054  832.802205
#      64           1.731094e-05      8472.172662  847.217266

# %% [markdown]
# ## 150 epoch

# %%
v1_150.groupby(['lags','nof_filters'])\
.agg({'mse(train)':['mean','median','var'],'mse(test)':['mean','median','var'],'calculation_time':['sum','mean']})
# Out:
#                  mse(train)                     mse(test)                      \
#                        mean    median       var      mean    median       var
# lags nof_filters
# 4    16            0.083341  0.082764  0.000004  0.059298  0.059284  0.000002
#      32            0.082113  0.080981  0.000006  0.058112  0.057504  0.000003
#      64            0.083359  0.083122  0.000005  0.059260  0.058769  0.000006
# 8    16            0.088115  0.088073  0.000003  0.061329  0.061112  0.000002
#      32            0.086089  0.085883  0.000006  0.060848  0.060350  0.000005
#      64            0.085872  0.085789  0.000002  0.060429  0.060182  0.000001
# 12   16            0.091969  0.091499  0.000009  0.062978  0.062255  0.000005
#      32            0.089991  0.089838  0.000008  0.062358  0.062066  0.000003
#      64            0.087635  0.086695  0.000011  0.060673  0.060467  0.000003
#
#                  calculation_time
#                               sum         mean
# lags nof_filters
# 4    16              13347.855395  1334.785540
#      32              13530.653097  1353.065310
#      64              13603.389174  1360.338917
# 8    16              13015.661200  1301.566120
#      32              13260.968158  1326.096816
#      64              13395.819113  1339.581911
# 12   16              12686.534532  1268.653453
#      32              12900.026412  1290.002641
#      64              13899.445223  1389.944522

# %%
v2_150.groupby(['lags','nof_filters'])\
.agg({'mse(train)':['mean','median','var'],'mse(test)':['mean','median','var'],'calculation_time':['sum','mean']})
# Out:
#                  mse(train)                     mse(test)            \
#                        mean    median       var      mean    median
# lags nof_filters
# 4    16            0.086602  0.086478  0.000003  0.063161  0.063064
#      32            0.085593  0.085543  0.000002  0.062331  0.061745
#      64            0.084973  0.084614  0.000003  0.061922  0.061559
# 8    16            0.091035  0.090542  0.000006  0.063217  0.062933
#      32            0.090327  0.090196  0.000005  0.063647  0.062977
#      64            0.089824  0.089488  0.000006  0.063131  0.062932
# 12   16            0.095518  0.094901  0.000033  0.065170  0.064553
#      32            0.093926  0.092708  0.000033  0.064677  0.063876
#      64            0.096026  0.095010  0.000016  0.065589  0.065397
#
#                                calculation_time
#                            var              sum         mean
# lags nof_filters
# 4    16           2.184941e-06     11983.309443  1198.330944
#      32           1.903608e-06     11792.411990  1179.241199
#      64           9.821526e-07     12030.850949  1203.085095
# 8    16           1.694414e-06     11980.747269  1198.074727
#      32           3.628099e-06     12202.263443  1220.226344
#      64           1.308568e-06     13590.806635  1359.080664
# 12   16           5.891692e-06     13209.367202  1320.936720
#      32           7.576210e-06     13281.425327  1328.142533
#      64           8.507680e-06     13218.542263  1321.854226

# %% [markdown]
# 에폭수를 늘린다고 해서 성능 개선이 없음..

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2,1) 
v1_50.boxplot(column='mse(test)', by=['lags', 'nof_filters'],ax= axes.flatten()[0])
v2_50.boxplot(column='mse(test)', by=['lags', 'nof_filters'],ax = axes.flatten()[1])
axes[0].set_ylim(0.055,0.08)
axes[1].set_ylim(0.055,0.08)
plt.suptitle('[50epoch] STGCN vs. EPT-STGCN ')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2,1) 
v1_100.boxplot(column='mse(test)', by=['lags', 'nof_filters'],ax= axes.flatten()[0])
v2_100.boxplot(column='mse(test)', by=['lags', 'nof_filters'],ax = axes.flatten()[1])
axes[0].set_ylim(0.055,0.08)
axes[1].set_ylim(0.055,0.08)
plt.suptitle('[100epoch] STGCN vs. EPT-STGCN ')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2,1) 
v1_150.boxplot(column='mse(test)', by=['lags', 'nof_filters'],ax= axes.flatten()[0])
v2_150.boxplot(column='mse(test)', by=['lags', 'nof_filters'],ax = axes.flatten()[1])
axes[0].set_ylim(0.055,0.08)
axes[1].set_ylim(0.055,0.08)
plt.suptitle('[150epoch] STGCN vs. EPT-STGCN ')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## calculation time

# %%
print(v1_50['calculation_time'].mean())
print(v2_50['calculation_time'].mean())
# Out:
# 420.6586783462101
# 396.9779078774982

# %%
print(v1_100['calculation_time'].mean())
print(v2_100['calculation_time'].mean())
# Out:
# 853.0324166483349
# 804.9077693329917

# %%
print(v1_150['calculation_time'].mean())
print(v2_150['calculation_time'].mean())
# Out:
# 1329.3372478379144
# 1258.77471689913

# %% [markdown]
# # LRNR

# %% [markdown]
# ref: <https://pinkocto.github.io/noteda/posts/SOLAR/2023-04-26-s-stgcn-ver2-150%EC%97%90%ED%8F%AD.html#visualization>

# %%
url = "https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data2/stgcn_data1.json"
url2 = "https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data4/stgcn_data2.json"
loader = eptstgcn.DatasetLoader(url)
loader2 = eptstgcn.DatasetLoader(url2)
dataset = loader.get_dataset(lags=4)
dataset2 = loader2.get_dataset(lags=4)

# %%
train_dataset, test_dataset = eptstgcn.utils.temporal_signal_split(dataset, train_ratio = 0.7)
train_dataset2, test_dataset2 = eptstgcn.utils.temporal_signal_split(dataset2, train_ratio = 0.7)

# %%
np.array(dataset.features).shape, np.array(dataset2.features).shape
# Out:
# ((2564, 44, 4), (2564, 44, 4))

# %%
lrnr = eptstgcn.StgcnLearner(train_dataset, dataset_name = 'data2(2022/06/01 ~ 2022/09/15)')

# %%
lrnr2 = eptstgcn.StgcnLearner(train_dataset2, dataset_name = 'data4(2022/06/01 ~ 2022/09/15)')

# %%
lrnr.learn(filters=32, epoch=100)
lrnr2.learn(filters=32, epoch=100)
# Out:
# 35/100

# %%
evtor = eptstgcn.Evaluator(lrnr, train_dataset, test_dataset)
evtor2 = eptstgcn.Evaluator(lrnr2, train_dataset2, test_dataset2)

# %% [markdown]
# ### Train

# %%
evtor.tr_plot(t=150, label='observed data')

# %%
evtor2.tr_plot(t=150, label='observed data')

# %% [markdown]
# ## Test

# %%
evtor.test_plot(t=150, label='observed data')

# %%
evtor2.test_plot(t=150, label='observed data')
