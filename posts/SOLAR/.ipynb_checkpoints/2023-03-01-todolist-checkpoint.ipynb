# %% [raw]
# ---
# title: " **[SOLAR]** To do list"
# author: "jiyunLim"
# date: "04/12/2023"
# categories:
#   - Research
#   - Score
# ---

# %% [markdown]
# # 지역별 여러 시계열
# > 04/12 update

# %% [markdown]
# ## --수정 (0412 update)
#
# - 데이터 중복문제
# - 데이터 기간 재설정: 6월-8월15 // 8월15 ~9월15
# - 가중치 데이터 새로
# - 가중치 스케일링 고려?

# %% [markdown]
# ## ARMA

# %% [markdown]
# <https://www.kaggle.com/code/javigallego/time-series-forecasting-tutorial#4-%7C-Time-Series-Components>

# %% [markdown]
# - 시계열 모델 돌릴때 이전에 임의로 결측값을 $0$으로 채운 것 다른방법으로도 채워서 해봐야하나??

# %% [markdown]
# ## LSTM

# %% [markdown]
# - <https://machinelearningmastery.com/lstm-for-time-series-prediction-in-pytorch/>
# - 가장 기본모델로 돌려보자.

# %% [markdown]
# ## GRU

# %% [markdown]
# ## STGCN
#
# - scaling이 필요할까..? (우선 스케일링안된 데이터 사용)

# %% [markdown]
# ![https://pinkocto.github.io/noteda/posts/SOLAR/2023-04-07-stcgn-data-ver2.html#comparison](attachment:b986b423-00dc-4308-af29-67de915f74fa.png)

# %% [markdown]
# ### STGCN Ver.1
#
# - 지역별 correlation
# - lag4 : $\tt{MSE}: 0.0934$ (약 1시간)

# %% [markdown]
# - lag1,2 등 정보가 더 적을때도 STGCN ver1이 더 좋은가?

# %% [markdown]
# ### STGCN Ver.2
#
# - envelope의 correlation
# - lag4:  $\tt{MSE}: 0.0938$ (약 1시간)

# %% [markdown]
# ## Score

# %%
import pandas as pd

# %%
col = ['Model', 'lag', 'epoch','learning rate','scaling','EPT', 'train(MSE)','test(MSE)', 'Time(sec)']

# %%
df_row = pd.DataFrame(columns = col)
df_row['Model'] = ['STGCN v1','STGCN v2','STGCN v1', 'STGCN v2']
df_row['lag'] = ['lag4', 'lag4', 'lag1', 'lag1']
df_row['epoch'] = [50, 50, 50, 50]
df_row['learning rate'] = [0.01, 0.01, 0.01, 0.01]
df_row['scaling'] = ['X', 'X', 'X', 'X']
df_row['EPT'] = ['X', 'O', 'X', 'O']
# df_row['Undersampling'] = ['X', 'X']
# df_row['hyper tunning'] = ['X', 'O']
df_row['train(MSE)'] = [0.1041, 0.1069,0.1695, 0.1711]
df_row['test(MSE)'] = [0.0934, 0.0938, 0.1443, 0.1452]
df_row['Time(sec)'] = ['약 1시간 (시간측정X)','약 1시간 (시간측정X)', '2916.28218 (약 48.60분)', '2888.63086 (약 48.14분)']

# %%
df_row
# Out:
#       Model   lag  epoch  learning rate scaling EPT  train(MSE)  test(MSE)  \
# 0  STGCN v1  lag4     50           0.01       X   X      0.1041     0.0934
# 1  STGCN v2  lag4     50           0.01       X   O      0.1069     0.0938
# 2  STGCN v1  lag1     50           0.01       X   X      0.1695     0.1443
# 3  STGCN v2  lag1     50           0.01       X   O      0.1711     0.1452
#
#                Time(sec)
# 0          약 1시간 (시간측정X)
# 1          약 1시간 (시간측정X)
# 2  2916.28218 (약 48.60분)
# 3  2888.63086 (약 48.14분)

# %% [markdown]
# `-` [STGCN ver1](https://pinkocto.github.io/noteda/posts/SOLAR/2023-04-07-soloar-stgcn-ver1-lag4.html#visualization)

# %% [markdown]
# ![STGCN ve1 lag4](attachment:72d65418-41e8-488f-baef-ca057bb6dc5b.png)

# %% [markdown]
# `-` [STGCN ver2](https://pinkocto.github.io/noteda/posts/SOLAR/2023-04-09-solar-stgcn-ver2-lag1.html#visualization)

# %% [markdown]
# ![STGCN ver2 lag4](attachment:4bb4ee9b-98e2-4adf-b4d0-63c4d3b69fd8.png)

# %% [markdown]
# - ver2가 더 성능이 잘 나올줄 알았는데 뭔가 잘못했나??
# - 시각화 그림을 보면 위에 가위로 자른 것 같이 생김. 일사량이 2.5이상으로 관측되면 잘 예측을 못하는 것 같음.
# - 맥시멈이 2.5인느낌. (너무 안전하게 예측하려고 하나?)
