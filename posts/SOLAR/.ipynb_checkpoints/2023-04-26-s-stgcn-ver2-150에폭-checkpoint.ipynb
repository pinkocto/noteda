# %% [raw]
# ---
# title: " **[SOLAR]** STGCN Ver2 (data2, -N +S) 30회 150 epoch"
# author: "JiyunLim"
# date: "04/26/2023"
# categories:
#   - Research
#   - STGCN
#   - SOLAR
# ---

# %% [markdown]
# # STGCN Ver2

# %% [markdown]
# ## ref
# - <https://github.com/miruetoto/yechan3/tree/main/posts/3_Researches/ITSTGCN/itstgcn>
# - <https://miruetoto.github.io/yechan3/posts/3_Researches/ITSTGCN/2023-03-18-SimulationPlanner-Tutorial.html#plnr_gnar_block>

# %% [markdown]
# ## 2022/06/01 ~ 2022/09/15
#
# - train 2022-06-01 00:00:00 ~ 2022-08-14 17:00:00
# - test 2022-08-14 18:00:00 ~ 2022-09-15 23:00:00

# %% [markdown]
# ## Import

# %%
import eptstgcn
import torch
import eptstgcn.planner

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
url = "https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data2/stgcn_data2.json"
loader = eptstgcn.DatasetLoader(url)
dataset = loader.get_dataset(lags=4)

# %%
train_dataset, test_dataset = eptstgcn.utils.temporal_signal_split(dataset, train_ratio = 0.7)

# %% [markdown]
# ## LRNR

# %% [markdown]
# - ref: <https://seoyeonc.github.io/blog/posts/GCN/2023-03-17-ITSTGCN-Tutorial.html>

# %%
lrnr = eptstgcn.StgcnLearner(train_dataset, dataset_name = 'data2(2022/06/01 ~ 2022/09/15)')

# %%
lrnr.learn(filters=32, epoch=150)
# Out:
# 150/150

# %%
import pickle 
with open('./lrnr_model/stgcn_ver2_data2_cancel_normal_150epoch.pickle','wb') as fw:
    pickle.dump(lrnr, fw)

# %%
import pickle 
with open('./lrnr_model/stgcn_ver2_data2_cancel_normal_150epoch.pickle', 'rb') as f: 
    model = pickle.load(f)

# %% [markdown]
# ## Visualization

# %%
evtor = eptstgcn.Evaluator(model, train_dataset, test_dataset)

# %%
# fig = evtor.plot('--', label='observed data')
# fig.tight_layout()
# fig

# %% [markdown]
# ### train

# %%
evtor.tr_plot(t=150, label='observed data')

# %% [markdown]
# ### test

# %%
evtor.test_plot(t=150, label='observed data')

# %% [markdown]
# ## Simulation

# %%
plans_stgcn = {
    'max_iteration': 30, 
    'method': ['EPT-STGCN'], 
    'lags': [4], 
    'nof_filters': [32], 
    'epoch': [150]
}

# %%
plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
plnr.simulate()
# Out:
# 1/30 is done
# 2/30 is done
# 3/30 is done
# 4/30 is done
# 5/30 is done
# 6/30 is done
# 7/30 is done
# 8/30 is done
# 9/30 is done
# 10/30 is done
# 11/30 is done
# 12/30 is done
# 13/30 is done
# 14/30 is done
# 15/30 is done
# 16/30 is done
# 17/30 is done
# 18/30 is done
# 19/30 is done
# 20/30 is done
# 21/30 is done
# 22/30 is done
# 23/30 is done
# 24/30 is done
# 25/30 is done
# 26/30 is done
# 27/30 is done
# 28/30 is done
# 29/30 is done
# 30/30 is done
# All results are stored in ./simulation_results/2023-04-27_22-16-11.csv

# %%
import pickle
with open('./simul_model/stgcn_ver2_data2_cancel_normal_150epoch.pickle', 'wb') as fw:
    pickle.dump(plnr, fw)

# %%
with open('./simul_model/stgcn_ver2_data2_cancel_normal_150epoch.pickle', 'rb') as f:
    simul_model = pickle.load(f)

# %%
df_simul_no = simul_model.simulation_results
df_simul_no
# Out:
#    dataset     method lags nof_filters epoch mse(train) mse(test)  \
# 0    data2  EPT-STGCN    4          32   150   0.185434  0.167638
# 1    data2  EPT-STGCN    4          32   150   0.193655  0.177747
# 2    data2  EPT-STGCN    4          32   150   0.184885  0.166774
# 3    data2  EPT-STGCN    4          32   150   0.182733  0.165493
# 4    data2  EPT-STGCN    4          32   150    0.19472  0.179478
# 5    data2  EPT-STGCN    4          32   150   0.189369  0.173464
# 6    data2  EPT-STGCN    4          32   150   0.188635  0.172912
# 7    data2  EPT-STGCN    4          32   150   0.189322  0.173068
# 8    data2  EPT-STGCN    4          32   150   0.201105   0.18462
# 9    data2  EPT-STGCN    4          32   150   0.191193   0.17579
# 10   data2  EPT-STGCN    4          32   150   0.192512  0.175854
# 11   data2  EPT-STGCN    4          32   150   0.184679  0.167099
# 12   data2  EPT-STGCN    4          32   150   0.202852   0.18948
# 13   data2  EPT-STGCN    4          32   150   0.188402  0.166038
# 14   data2  EPT-STGCN    4          32   150   0.191666  0.175607
# 15   data2  EPT-STGCN    4          32   150   0.194334  0.177816
# 16   data2  EPT-STGCN    4          32   150   0.185386  0.165209
# 17   data2  EPT-STGCN    4          32   150   0.184355  0.165018
# 18   data2  EPT-STGCN    4          32   150   0.189528  0.168143
# 19   data2  EPT-STGCN    4          32   150   0.189098  0.166917
# 20   data2  EPT-STGCN    4          32   150   0.191017  0.174641
# 21   data2  EPT-STGCN    4          32   150   0.189909  0.174315
# 22   data2  EPT-STGCN    4          32   150   0.188329  0.169955
# 23   data2  EPT-STGCN    4          32   150    0.19075  0.169495
# 24   data2  EPT-STGCN    4          32   150   0.190843  0.175025
# 25   data2  EPT-STGCN    4          32   150   0.189308  0.167444
# 26   data2  EPT-STGCN    4          32   150   0.190253  0.174134
# 27   data2  EPT-STGCN    4          32   150   0.188167  0.169744
# 28   data2  EPT-STGCN    4          32   150   0.194325  0.177916
# 29   data2  EPT-STGCN    4          32   150   0.190294  0.169708
#
#    calculation_time
# 0       3469.144449
# 1       3484.422505
# 2       3117.519283
# 3        3578.09566
# 4       3367.387573
# 5       3462.885302
# 6       3383.795394
# 7       3309.909593
# 8       3457.644482
# 9       3350.393971
# 10      3049.338518
# 11      1396.975266
# 12      1221.331869
# 13      1219.885355
# 14      1221.502784
# 15      1222.205302
# 16      1222.540227
# 17      1225.328879
# 18      1223.233369
# 19      1227.838187
# 20      1225.812665
# 21      1227.123315
# 22      1227.044582
# 23      1229.764893
# 24      1229.049209
# 25      1530.840858
# 26      3743.438032
# 27      4029.448345
# 28      4092.016257
# 29      4100.476865

# %%
df_simul_no['mse(test)'].mean()
# Out:
# 0.17255143771568934

# %%
print('끝')
# Out:
# 끝

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_simul_no['mse(test)'])
plt.show()
