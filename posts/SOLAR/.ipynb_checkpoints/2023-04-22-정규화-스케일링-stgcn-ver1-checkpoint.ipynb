# %% [raw]
# ---
# title: " **[SOLAR]** STGCN Ver1 (data2, +N +S) 30회"
# author: "JiyunLim"
# date: "04/22/2023"
# categories:
#   - Research
#   - STGCN
#   - SOLAR
# ---

# %% [markdown]
# # STGCN Ver1

# %% [markdown]
# ## ref
# - <https://github.com/miruetoto/yechan3/tree/main/posts/3_Researches/ITSTGCN/itstgcn>
# - <https://miruetoto.github.io/yechan3/posts/3_Researches/ITSTGCN/2023-03-18-SimulationPlanner-Tutorial.html#plnr_gnar_block>

# %% [markdown]
# ## 2022/06/01 ~ 2022/09/15
#
# - train 2022-06-01 00:00:00 ~ 2022-08-14 17:00:00
# - test 2022-08-14 18:00:00 ~ 2022-09-15 23:00:00

# %% [markdown]
# ## import

# %%
import eptstgcn
import torch
import eptstgcn.planner

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
url = "https://raw.githubusercontent.com/pinkocto/noteda/main/posts/SOLAR/data2/stgcn_data1.json"
loader = eptstgcn.DatasetLoader(url)
dataset = loader.get_dataset(lags=4)

# %%
train_dataset, test_dataset = eptstgcn.utils.temporal_signal_split(dataset, train_ratio = 0.7)

# %% [markdown]
# ## LRNR

# %%
# lrnr = eptstgcn.StgcnLearner(train_dataset, dataset_name = 'data2(2022/06/01 ~ 2022/09/15)')
# Out:
# /home/jy/Dropbox/noteda/posts/SOLAR/eptstgcn/learners.py:50: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1678402421473/work/torch/csrc/utils/tensor_new.cpp:245.)
#   self.lags = torch.tensor(train_dataset.features).shape[-1]

# %%
# lrnr.learn(filters=32, epoch=50)
# Out:
# 49/50

# %%
# import pickle 
# with open('./lrnr_model/stgcn_ver1_data2.pickle','wb') as fw:
#     pickle.dump(lrnr, fw)

# %%
import pickle 
with open('./lrnr_model/stgcn_ver1_data2.pickle', 'rb') as f: 
    lrnr_model = pickle.load(f)

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### train

# %%
evtor = eptstgcn.Evaluator(lrnr_model, train_dataset, test_dataset)
# Out:
# /home/jy/Dropbox/noteda/posts/SOLAR/eptstgcn/learners.py:70: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1678402421473/work/torch/csrc/utils/tensor_new.cpp:245.)
#   X = torch.tensor(dataset.features).float()

# %%
evtor.tr_plot(t=150, label='observed data')
# Out:
# /home/jy/Dropbox/noteda/posts/SOLAR/eptstgcn/utils.py:288: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.tight_layout()
# /home/jy/anaconda3/envs/torch/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### test

# %%
evtor.test_plot(t=150, label='observed data')

# %% [markdown]
# ## Simulation

# %%
plans_stgcn = {
    'max_iteration': 30, 
    'method': ['STGCN'], 
    'lags': [4], 
    'nof_filters': [32], 
    'epoch': [50]
}

# %%
# plnr = eptstgcn.planner.PLNR_STGCN(plans_stgcn,loader,dataset_name='data2')

# %%
# plnr.simulate()
# Out:
# 1/30 is done
# 2/30 is done
# 3/30 is done
# 4/30 is done
# 5/30 is done
# 6/30 is done
# 7/30 is done
# 8/30 is done
# 9/30 is done
# 10/30 is done
# 11/30 is done
# 12/30 is done
# 13/30 is done
# 14/30 is done
# 15/30 is done
# 16/30 is done
# 17/30 is done
# 18/30 is done
# 19/30 is done
# 20/30 is done
# 21/30 is done
# 22/30 is done
# 23/30 is done
# 24/30 is done
# 25/30 is done
# 26/30 is done
# 27/30 is done
# 28/30 is done
# 29/30 is done
# 30/30 is done
# All results are stored in ./simulation_results/2023-04-20_11-04-27.csv

# %%
# import pickle
# with open('./simul_model/stgcn_ver1_data2.pickle','wb') as fw:
#          pickle.dump(plnr, fw)

# %%
# import pickle
with open('./simul_model/stgcn_ver1_data2.pickle', 'rb') as f:
          simul_model = pickle.load(f)

# %%
df_simul = simul_model.simulation_results
df_simul
# Out:
#    dataset method lags nof_filters epoch       mse calculation_time
# 0    data2  STGCN    4          32    50  0.183838       297.827193
# 1    data2  STGCN    4          32    50  0.197644        297.39739
# 2    data2  STGCN    4          32    50  0.174572       344.664682
# 3    data2  STGCN    4          32    50  0.175856       412.458746
# 4    data2  STGCN    4          32    50  0.183391       403.818523
# 5    data2  STGCN    4          32    50  0.182653       412.442706
# 6    data2  STGCN    4          32    50  0.173357       364.271884
# 7    data2  STGCN    4          32    50  0.180988       299.365499
# 8    data2  STGCN    4          32    50  0.194996       300.316778
# 9    data2  STGCN    4          32    50  0.192895       300.115653
# 10   data2  STGCN    4          32    50  0.171724       299.164049
# 11   data2  STGCN    4          32    50  0.178121       299.819023
# 12   data2  STGCN    4          32    50  0.174512       300.490552
# 13   data2  STGCN    4          32    50  0.175112       299.584245
# 14   data2  STGCN    4          32    50  0.180143       300.218299
# 15   data2  STGCN    4          32    50  0.180791       300.689956
# 16   data2  STGCN    4          32    50  0.166162       301.706746
# 17   data2  STGCN    4          32    50  0.182529        299.56468
# 18   data2  STGCN    4          32    50  0.176125       300.486649
# 19   data2  STGCN    4          32    50  0.177237       299.198548
# 20   data2  STGCN    4          32    50  0.181495       299.831336
# 21   data2  STGCN    4          32    50   0.19002       301.643143
# 22   data2  STGCN    4          32    50  0.179018        299.06001
# 23   data2  STGCN    4          32    50  0.176116       299.344622
# 24   data2  STGCN    4          32    50  0.199659       299.757764
# 25   data2  STGCN    4          32    50  0.177913       299.740376
# 26   data2  STGCN    4          32    50  0.191579       299.844217
# 27   data2  STGCN    4          32    50  0.181708       412.672964
# 28   data2  STGCN    4          32    50  0.174949       428.429988
# 29   data2  STGCN    4          32    50  0.189599       298.493461

# %%
import matplotlib.pyplot as plt
plt.boxplot(df_simul['mse'])
plt.show()
