# %% [raw]
# ---
# title: " 학회 "
# author: "JiyunLim"
# date: "04/20/2023"
# ---

# %% [markdown]
# ## 학술정보 참고사이트

# %% [markdown]
# <https://sejong-kr.libguides.com/c.php?g=936487&p=6772760>

# %% [markdown]
# 자료분석학회, 데이터마이닝학회

# %% [markdown]
# - 통계학회(4/20), 한국빅데이터학회(4/17), 한국데이터정보과학회(4/21),정보처리학회(4/19) $\to$ "마감"
# - 자료분석학회(5/29 발표신청, 5/31 초록/논문제출)
# - 데이터마이닝학회(5/5 초록제출, 5/12 논문선정통보, 6/16 발표논문제출)

# %% [markdown]
# ## [통계학회](http://www.kss.or.kr/) (마감) (6월29일~7월1일)
#
# - [학술대회 모집공고](http://www.kss.or.kr/bbs/board.php?bo_table=conferenceInfo&wr_id=50)

# %% [markdown]
# ***4/20일까지 초록(1페이지)과 발표요약본(A4 5장내외) 제출필요***

# %% [markdown]
# ￭ 일 시 : 2023년 6월 29일(목)-7월 1일(토)
#
# ￭ 장 소 : 부경대학교
#
# ￭ 주 최 : (사)한국통계학회
#
# ￭ 주 관 : (사)한국통계학회, 부경대학교 통계·데이터사이언스전공

# %% [markdown]
# - [발표논문초록템플릿](http://www.kss.or.kr/bbs/board.php?bo_table=thesisInfo)
# - 초록분량 1페이지 이내
# - 석사생의 경우 별도로 발표요약본을 추가로 제출해야함.(A4 5장 내외)

# %% [markdown]
# ![일정](attachment:53e54a4d-9d27-4d70-919d-a6d11e67447c.png)

# %% [markdown]
# ### 논문발표신청 일정

# %% [markdown]
# ![논문발표신청일정](attachment:3bc66c46-33e5-440a-ad6c-f84ec8ae976d.png)

# %% [markdown]
# ### 초록양식 및 제출방법

# %% [markdown]
# ![image.png](attachment:ca7b2503-02c8-4a3c-b1eb-a8162eecfd77.png)

# %% [markdown]
# ### 초록 탬플릿 예시

# %% [markdown]
# ![초록템플릿](attachment:f02ec732-689f-45fd-b36c-975a2ca3e03a.png)

# %% [markdown]
# ## [한국데이터마이닝학회](http://www.kdms.or.kr/) (6월23일-24일)
#
# - [하계학술대회 모집공고](http://www.kdms.or.kr/bbs/board.php?bo_table=notice&wr_id=27)

# %% [markdown]
# KDMS 2023 하계학술대회가 "챗GPT AI 시대 속에서 데이터마이닝의 역할"이라는 주제로 강릉원주대학교에서 6월 23일(금)-24(토) 양일에 걸쳐 개최됩니다.

# %% [markdown]
# ### 논문발표신청 및 등록일정

# %% [markdown]
# #### ▣ 일반 논문 발표신청
#
# - 사전 등록: 5월 22일(월) ~ 6월 22일(목) - 학생 7만, 일반 14만
#
# - 초록 제출: 5월 5일 (금)
#
# - 선정 통보: 5월 7일 (금)
#
# - 논문 제출: 6월 16일 (금)
#
# - 일정: 6월 23일(금) ~ 6월 24일(토)
#
#
# - 제출처: <https://forms.gle/5CRQhxUqwAmbo5iu7>

# %% [markdown]
# ### 논문모집분야

# %% [markdown]
# > 일반논문, SAS학생논문 모집중.

# %% [markdown]
# ![image.png](attachment:2b9ec9b8-cc3d-40bb-b7f2-1c0f61b11a5a.png)

# %% [markdown]
# ## [자료분석학회](http://www.kdas.or.kr/index.ink) (7월6일~7월7일)

# %% [markdown]
# - 일시: 2023년 7월 6일 (목) ~ 7월 7일 (금)
# - 장소: 고려대학교 (서울특별시 성북구안암로 145)
# - [**발표신청**](https://forms.gle/4di4XxqzZxZzELiX8) : 2023년 5월 29일 (월) 까지
# - 초록/논문제출: 2023년 5월 31일(수) 까지
#     - 초록 1페이지, 논문 4쪽이내
# - 사전등록기간: 2023년 4월 1일(토) ~ 2023년 5월 31일(수)
# - 등록비(사전등록): 일반회원 50000원, 학생회원 30000원

# %% [markdown]
# ![자료분석학회 타임라인](attachment:3457647e-ac37-4174-a210-9eaef27d9602.png)

# %% [markdown]
# ![일정](attachment:a7dc1984-ddb9-4744-9387-b71aef7dda0b.png)
