# %% [raw]
# ---
# title: "Julia 설치 및 실행"
# author: "jiyun Lim"
# date: "02/24/2023"
# categories:
#   - Tip
# ---

# %% [markdown]
# ## Jupter에서 Julia 연동하여 사용하기

# %% [markdown]
# 1. Julia 설치
#
# 2. 설치된 Julia를 열어 Command창에  **`using Pkg`** 입력 + 엔터
#
# 3. **`Pkg.add("IJulia")`** 입력 + 엔터
#
# 4. Jupyter notebook/lab 들어가서 확인

# %% [markdown]
# **결과**

# %% [markdown]
# ![image.png](attachment:53842c39-a26e-4b36-85fa-6f47c342bce5.png)

# %% [markdown]
# ## Linux
#
# ### 1. 줄리아 설치
#
# ```python
# ## 설치
# >> sudo apt install wget ## wget 설치가 안되어 있다면
# >> wget https://julialang-s3.julialang.org/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz
# ```
#
# ![julia 설치되고 있는 화면 캡처](attachment:47211b9a-9c70-4d5d-bba6-d77fc2e36209.png)
#
# ```python
# ## 압축풀기
# >> tar zxvf julia-1.8.5-linux-x86_64.tar.gz
# ```
#
# ```python
# ## 심볼릭 링크 만들기
# >> sudo ln -s /home/[유저이름]/julia-1.3.1/bin/julia /usr/bin/julia
# ```
#
# ### 2. 주피터와 연결
#
#
# ```python
# ## julia 실행
# >> julia
# >> using Pkg
# >> Pkg.add("IJulia")
# ```
#
# ### 3. 플루토 키는 방법
#
# ```python
# import Pluto
# Pluto.run(host="0.0.0.0",port=1234,launch_browser=false,require_secret_for_open_links=false,require_secret_for_access=false,threads="8")
# ```

# %% [markdown]
# - ref: https://miruetoto.github.io/yechan3/posts/4_Notes/2000-01-07-%EC%A4%84%EB%A6%AC%EC%95%84%20%EC%84%A4%EC%B9%98%20%EB%B0%8F%20%EC%8B%A4%ED%96%89.html
# - ref: https://freshrimpsushi.github.io/posts/how-to-install-the-latest-version-julia-in-linux/

# %% [markdown]
# # 리눅스 한글깨짐

# %% [markdown]
# ref: <https://bskyvision.com/entry/matplotlib-%EB%A6%AC%EB%88%85%EC%8A%A4-%EC%9A%B0%EB%B6%84%ED%88%AC-matplotlib-%EA%B7%B8%EB%9E%98%ED%94%84-%ED%95%9C%EA%B8%80-%EA%B9%A8%EC%A7%90-%EB%AC%B8%EC%A0%9C-%ED%95%B4%EA%B2%B0%EB%B2%95>
