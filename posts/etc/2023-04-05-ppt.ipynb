# %% [raw]
# ---
# title: "ppt 폰트"
# author: "jiyunLim"
# date: "04/05/2023"
# categories:
#   - ppt
# ---

# %% [markdown]
# ![https://m.blog.naver.com/yeeeeeei/220672713797](attachment:bbdb4506-8fc3-4fd6-b7fe-5ab5a7634890.png)
