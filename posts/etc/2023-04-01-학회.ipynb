# %% [raw]
# ---
# title: " 학회 "
# author: "JiyunLim"
# date: "04/01/2023"
# ---

# %% [markdown]
# - [통계학회](http://www.kss.or.kr/bbs/board.php?bo_table=conferenceInfo&wr_id=50)
# - [데이터마이닝학회](http://www.kdms.or.kr/)

# %% [markdown]
# ## [통계학회](http://www.kss.or.kr/)
#
# - [학술대회 모집공고](http://www.kss.or.kr/bbs/board.php?bo_table=conferenceInfo&wr_id=50)

# %% [markdown]
# ￭ 일 시 : 2023년 6월 29일(목)-7월 1일(토)
#
# ￭ 장 소 : 부경대학교
#
# ￭ 주 최 : (사)한국통계학회
#
# ￭ 주 관 : (사)한국통계학회, 부경대학교 통계·데이터사이언스전공

# %% [markdown]
# - [발표논문초록템플릿](http://www.kss.or.kr/bbs/board.php?bo_table=thesisInfo)
# - 초록분량 1페이지 이내
# - 석사생의 경우 별도로 발표요약본을 추가로 제출해야함.(A4 5장 내외)

# %% [markdown]
# ### 논문발표신청 일정

# %% [markdown]
# ![논문발표신청일정](attachment:3bc66c46-33e5-440a-ad6c-f84ec8ae976d.png)

# %% [markdown]
# ### 초록양식 및 제출방법

# %% [markdown]
# ![image.png](attachment:ca7b2503-02c8-4a3c-b1eb-a8162eecfd77.png)

# %% [markdown]
# ### 초록 탬플릿 예시

# %% [markdown]
# ![초록템플릿](attachment:f02ec732-689f-45fd-b36c-975a2ca3e03a.png)

# %% [markdown]
# ## [한국데이터마이닝학회](http://www.kdms.or.kr/)

# %% [markdown]
# - [하계학술대회 모집공고](http://www.kdms.or.kr/bbs/board.php?bo_table=notice&wr_id=27)

# %% [markdown]
# ### 논문발표신청 및 등록일정

# %% [markdown]
# #### ▣​ 일반 논문 발표신청​
#
# ▶️​ 초록 제출: 5월 5일 (금)​​
#
# ▶️​ 선정 통보: 5월 7일 (금)
#
# ▶️​ 논문 제출: 6월 16일 (금)
#
# ▶️ 제출처: <https://forms.gle/5CRQhxUqwAmbo5iu7>

# %% [markdown]
# #### ▣​ SAS 학생 논문
#
# ▶️​ 초록 및 논문 제출: 6월 9일 (금)
#
# ▶️​ 1차 심사 결과통보: 6월 16일 (금)
#
# ▶️​ 제출 양식 : http://kdms.or.kr/bbs/board.php?bo_table=reference&wr_id=4​
#
# ▶️ 제출처: 사무국 e-mail (KDMSoffice@gmail.com)

# %% [markdown]
# #### ▣ 등록
#
# ▶️​ 얼리버드 할인 등록: 현재 ~ 5월 21일 (일) - 학생 6만, 일반 12만
#
# ▶️​ 사전 등록: 5월 22일(월) ~ 6월 22일(목) - 학생 7만, 일반 14만
#
# ▶️​ 현장 등록: 6월 23일(금) ~ 6월 24일(토) - 학생 8만, 일반 16만

# %% [markdown]
# ### 논문모집분야

# %% [markdown]
# > 일반논문, SAS학생논문 모집중.

# %% [markdown]
# ![image.png](attachment:2b9ec9b8-cc3d-40bb-b7f2-1c0f61b11a5a.png)
