# %%
library(car)
# Out:
# Loading required package: carData

# %%
?States
# Out:
# States                 package:carData                 R Documentation
#
# s
#
# n:
#
#      The ‘States’ data frame has 51 rows and 8 columns.  The
#      observations are the U. S. states and Washington, D. C.
#
# e:
#
#      States
#
# t:
#
#      This data frame contains the following columns:
#
#      region U. S. Census regions.  A factor with levels: ‘ENC’, East
#           North Central; ‘ESC’, East South Central; ‘MA’, Mid-Atlantic;
#           ‘MTN’, Mountain; ‘NE’, New England; ‘PAC’, Pacific; ‘SA’,
#           South Atlantic; ‘WNC’, West North Central; ‘WSC’, West South
#           Central.
#
#      pop Population: in 1,000s.
#
#      SATV Average score of graduating high-school students in the state
#           on the _verbal_ component of the Scholastic Aptitude Test (a
#           standard university admission exam).
#
#      SATM Average score of graduating high-school students in the state
#           on the _math_ component of the Scholastic Aptitude Test.
#
# ...

# %%
library(tidyverse)

# %%
cor(States$SATV, (States$percent)*100)
# Out:
# [1] -0.8627954
